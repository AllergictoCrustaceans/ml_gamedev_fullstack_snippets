# %% [markdown]
# # Dermatology Diseases
#
# ## Data to  Use
# The following dataset came from [Kaggle](https://www.kaggle.com/datasets/olcaybolat1/dermatology-dataset-classification)
#
# ## Define Problem
# Given a patient's medical information, predict what type of dermatological Eryhemato-Squamous disease they have.
# This is a multi-classification ML task.
# - 0: Psoriasis
# - 1: Deborrheic dermatitis
# - 2: Lichen Planus
# - 3: Pityriasis rosea
# - 4: Chronic dermatitis
# - 5: Pityriasis rubra pilaris
#
# ## Define Evaluation Metrics
# If I can train a model to predict the type of dermatological disease with an accuracy rate of 95%+, then we can move forward with implementing an application. (but honestly, I have no idea what real business metric to set this by)
#
#
# ## Define Features to Use
#      0   erythema                             366 non-null    int64
#      1   scaling                              366 non-null    int64
#      2   definite_borders                     366 non-null    int64
#      3   itching                              366 non-null    int64
#      4   koebner_phenomenon                   366 non-null    int64
#      5   polygonal_papules                    366 non-null    int64
#      6   follicular_papules                   366 non-null    int64
#      7   oral_mucosal_involvement             366 non-null    int64
#      8   knee_and_elbow_involvement           366 non-null    int64
#      9   scalp_involvement                    366 non-null    int64
#      10  family_history                       366 non-null    int64
#      11  melanin_incontinence                 366 non-null    int64
#      12  eosinophils_infiltrate               366 non-null    int64
#      13  PNL_infiltrate                       366 non-null    int64
#      14  fibrosis_papillary_dermis            366 non-null    int64
#      15  exocytosis                           366 non-null    int64
#      16  acanthosis                           366 non-null    int64
#      17  hyperkeratosis                       366 non-null    int64
#      18  parakeratosis                        366 non-null    int64
#      19  clubbing_rete_ridges                 366 non-null    int64
#      20  elongation_rete_ridges               366 non-null    int64
#      21  thinning_suprapapillary_epidermis    366 non-null    int64
#      22  spongiform_pustule                   366 non-null    int64
#      23  munro_microabcess                    366 non-null    int64
#      24  focal_hypergranulosis                366 non-null    int64
#      25  disappearance_granular_layer         366 non-null    int64
#      26  vacuolisation_damage_basal_layer     366 non-null    int64
#      27  spongiosis                           366 non-null    int64
#      28  saw_tooth_appearance_retes           366 non-null    int64
#      29  follicular_horn_plug                 366 non-null    int64
#      30  perifollicular_parakeratosis         366 non-null    int64
#      31  inflammatory_mononuclear_infiltrate  366 non-null    int64
#      32  band_like_infiltrate                 366 non-null    int64
#      33  age                                  366 non-null    object
#      34  class                                366 non-null    int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# preprocess
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder


# modeling
import xgboost as xgb
import lightgbm as lgbm
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis


# evaluation
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import RocCurveDisplay

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("data/dermatology_database_1.csv", delimiter=",")
df
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon
# 0           2        2                 0        3                   0  \
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement
# 0                    0                   0                         0  \
# 1                    0                   0                         0
# 2                    3                   0                         3
# 3                    0                   0                         0
# 4                    2                   0                         2
# ..                 ...                 ...                       ...
# 361                  0                   0                         0
# 362                  0                   0                         0
# 363                  2                   0                         2
# 364                  3                   0                         2
# 365                  0                   0                         0
#
#      knee_and_elbow_involvement  scalp_involvement  ...
# 0                             1                  0  ...  \
# 1                             1                  1  ...
# 2                             0                  0  ...
# 3                             3                  2  ...
# 4                             0                  0  ...
# ..                          ...                ...  ...
# 361                           0                  0  ...
# 362                           0                  0  ...
# 363                           0                  0  ...
# 364                           0                  0  ...
# 365                           3                  3  ...
#
#      disappearance_granular_layer  vacuolisation_damage_basal_layer
# 0                               0                                 0  \
# 1                               0                                 0
# 2                               0                                 2
# 3                               3                                 0
# 4                               2                                 3
# ..                            ...                               ...
# 361                             0                                 0
# 362                             1                                 0
# 363                             0                                 3
# 364                             0                                 2
# 365                             2                                 0
#
#      spongiosis  saw_tooth_appearance_retes  follicular_horn_plug
# 0             3                           0                     0  \
# 1             0                           0                     0
# 2             3                           2                     0
# 3             0                           0                     0
# 4             2                           3                     0
# ..          ...                         ...                   ...
# 361           1                           0                     0
# 362           1                           0                     0
# 363           0                           3                     0
# 364           0                           1                     0
# 365           0                           0                     0
#
#      perifollicular_parakeratosis  inflammatory_mononuclear_infiltrate
# 0                               0                                    1  \
# 1                               0                                    1
# 2                               0                                    2
# 3                               0                                    3
# 4                               0                                    2
# ..                            ...                                  ...
# 361                             0                                    2
# 362                             0                                    2
# 363                             0                                    2
# 364                             0                                    2
# 365                             0                                    3
#
#      band_like_infiltrate  age  class
# 0                       0   55      2
# 1                       0    8      1
# 2                       3   26      3
# 3                       0   40      1
# 4                       3   45      3
# ..                    ...  ...    ...
# 361                     0   25      4
# 362                     0   36      4
# 363                     3   28      3
# 364                     3   50      3
# 365                     0   35      1
#
# [366 rows x 35 columns]

# %% [markdown]
# ## Exporatory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   erythema                             366 non-null    int64
#  1   scaling                              366 non-null    int64
#  2   definite_borders                     366 non-null    int64
#  3   itching                              366 non-null    int64
#  4   koebner_phenomenon                   366 non-null    int64
#  5   polygonal_papules                    366 non-null    int64
#  6   follicular_papules                   366 non-null    int64
#  7   oral_mucosal_involvement             366 non-null    int64
#  8   knee_and_elbow_involvement           366 non-null    int64
#  9   scalp_involvement                    366 non-null    int64
#  10  family_history                       366 non-null    int64
#  11  melanin_incontinence                 366 non-null    int64
#  12  eosinophils_infiltrate               366 non-null    int64
#  13  PNL_infiltrate                       366 non-null    int64
#  14  fibrosis_papillary_dermis            366 non-null    int64
#  15  exocytosis                           366 non-null    int64
#  16  acanthosis                           366 non-null    int64
#  17  hyperkeratosis                       366 non-null    int64
#  18  parakeratosis                        366 non-null    int64
#  19  clubbing_rete_ridges                 366 non-null    int64
#  20  elongation_rete_ridges               366 non-null    int64
#  21  thinning_suprapapillary_epidermis    366 non-null    int64
#  22  spongiform_pustule                   366 non-null    int64
#  23  munro_microabcess                    366 non-null    int64
#  24  focal_hypergranulosis                366 non-null    int64
#  25  disappearance_granular_layer         366 non-null    int64
#  26  vacuolisation_damage_basal_layer     366 non-null    int64
#  27  spongiosis                           366 non-null    int64
#  28  saw_tooth_appearance_retes           366 non-null    int64
#  29  follicular_horn_plug                 366 non-null    int64
#  30  perifollicular_parakeratosis         366 non-null    int64
#  31  inflammatory_mononuclear_infiltrate  366 non-null    int64
#  32  band_like_infiltrate                 366 non-null    int64
#  33  age                                  366 non-null    object
#  34  class                                366 non-null    int64
# dtypes: int64(34), object(1)
# memory usage: 100.2+ KB

# %% [markdown]
# **Note**:
# - The 'age' feature is an object. It should be numerical. Keep this in mind as part of the data cleaning to convert this feature from object to int64.
# - Most of these features are integers, but these numbers are associated to categorical features. Keep this in mind as we preprocess which features are categorical variables.

# %% [markdown]
# ### Missing Values Analysis

# %%
df_bool = (df == "?")

# %%
df_bool.sum()
# Out:
# erythema                               0
# scaling                                0
# definite_borders                       0
# itching                                0
# koebner_phenomenon                     0
# polygonal_papules                      0
# follicular_papules                     0
# oral_mucosal_involvement               0
# knee_and_elbow_involvement             0
# scalp_involvement                      0
# family_history                         0
# melanin_incontinence                   0
# eosinophils_infiltrate                 0
# PNL_infiltrate                         0
# fibrosis_papillary_dermis              0
# exocytosis                             0
# acanthosis                             0
# hyperkeratosis                         0
# parakeratosis                          0
# clubbing_rete_ridges                   0
# elongation_rete_ridges                 0
# thinning_suprapapillary_epidermis      0
# spongiform_pustule                     0
# munro_microabcess                      0
# focal_hypergranulosis                  0
# disappearance_granular_layer           0
# vacuolisation_damage_basal_layer       0
# spongiosis                             0
# saw_tooth_appearance_retes             0
# follicular_horn_plug                   0
# perifollicular_parakeratosis           0
# inflammatory_mononuclear_infiltrate    0
# band_like_infiltrate                   0
# age                                    8
# class                                  0
# dtype: int64

# %% [markdown]
# **Note**: Looks like there are 8 sample missing the 'age' feature. In order to determine how to impute these values, I wish to see how much of an impact 'age' has on determining the type of disease. If there is little to no significance between the two variables, then I may consider dropping these 8 values.

# %% [markdown]
# ### Distribution of Each Attribute

# %%
df.dtypes
# Out:
# erythema                                int64
# scaling                                 int64
# definite_borders                        int64
# itching                                 int64
# koebner_phenomenon                      int64
# polygonal_papules                       int64
# follicular_papules                      int64
# oral_mucosal_involvement                int64
# knee_and_elbow_involvement              int64
# scalp_involvement                       int64
# family_history                          int64
# melanin_incontinence                    int64
# eosinophils_infiltrate                  int64
# PNL_infiltrate                          int64
# fibrosis_papillary_dermis               int64
# exocytosis                              int64
# acanthosis                              int64
# hyperkeratosis                          int64
# parakeratosis                           int64
# clubbing_rete_ridges                    int64
# elongation_rete_ridges                  int64
# thinning_suprapapillary_epidermis       int64
# spongiform_pustule                      int64
# munro_microabcess                       int64
# focal_hypergranulosis                   int64
# disappearance_granular_layer            int64
# vacuolisation_damage_basal_layer        int64
# spongiosis                              int64
# saw_tooth_appearance_retes              int64
# follicular_horn_plug                    int64
# perifollicular_parakeratosis            int64
# inflammatory_mononuclear_infiltrate     int64
# band_like_infiltrate                    int64
# age                                    object
# class                                   int64
# dtype: object

# %% [markdown]
# ### Class Distribution

# %%
df['class'].value_counts().plot(kind="bar", color=["lightgreen","yellow", "lightblue", "red", "salmon", "brown"])
plt.title("Number of Different Class Labels")
plt.xticks(rotation=0)
plt.ylabel("Amount")
plt.xlabel("Classes")
plt.show()

# %% [markdown]
# ### Outlier Detection

# %% [markdown]
# ### EDA Takeaways:

# %% [markdown]
# ## Data Cleaning

# %%
categorical_features = [
    'erythema', 
    'scaling', 
    'definite_borders', 
    'itching',
    'koebner_phenomenon', 
    'polygonal_papules', 
    'follicular_papules',
    'oral_mucosal_involvement', 
    'knee_and_elbow_involvement',
    'scalp_involvement', 
    'family_history', 
    'melanin_incontinence',
    'eosinophils_infiltrate', 
    'PNL_infiltrate', 
    'fibrosis_papillary_dermis',
    'exocytosis', 
    'acanthosis', 
    'hyperkeratosis', 
    'parakeratosis',
    'clubbing_rete_ridges', 
    'elongation_rete_ridges',
    'thinning_suprapapillary_epidermis', 
    'spongiform_pustule',
    'munro_microabcess', 
    'focal_hypergranulosis',
    'disappearance_granular_layer', 
    'vacuolisation_damage_basal_layer',
    'spongiosis', 
    'saw_tooth_appearance_retes', 
    'follicular_horn_plug',
    'perifollicular_parakeratosis', 
    'inflammatory_mononuclear_infiltrate',
    'band_like_infiltrate']

# %% [markdown]
# ### Remove Missing Data

# %%
# drop the 8 unknown cells from age column
df['age'] = df['age'].replace('?', np.nan)
df.dropna(subset=['age'], inplace=True)
df
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon
# 0           2        2                 0        3                   0  \
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement
# 0                    0                   0                         0  \
# 1                    0                   0                         0
# 2                    3                   0                         3
# 3                    0                   0                         0
# 4                    2                   0                         2
# ..                 ...                 ...                       ...
# 361                  0                   0                         0
# 362                  0                   0                         0
# 363                  2                   0                         2
# 364                  3                   0                         2
# 365                  0                   0                         0
#
#      knee_and_elbow_involvement  scalp_involvement  ...
# 0                             1                  0  ...  \
# 1                             1                  1  ...
# 2                             0                  0  ...
# 3                             3                  2  ...
# 4                             0                  0  ...
# ..                          ...                ...  ...
# 361                           0                  0  ...
# 362                           0                  0  ...
# 363                           0                  0  ...
# 364                           0                  0  ...
# 365                           3                  3  ...
#
#      disappearance_granular_layer  vacuolisation_damage_basal_layer
# 0                               0                                 0  \
# 1                               0                                 0
# 2                               0                                 2
# 3                               3                                 0
# 4                               2                                 3
# ..                            ...                               ...
# 361                             0                                 0
# 362                             1                                 0
# 363                             0                                 3
# 364                             0                                 2
# 365                             2                                 0
#
#      spongiosis  saw_tooth_appearance_retes  follicular_horn_plug
# 0             3                           0                     0  \
# 1             0                           0                     0
# 2             3                           2                     0
# 3             0                           0                     0
# 4             2                           3                     0
# ..          ...                         ...                   ...
# 361           1                           0                     0
# 362           1                           0                     0
# 363           0                           3                     0
# 364           0                           1                     0
# 365           0                           0                     0
#
#      perifollicular_parakeratosis  inflammatory_mononuclear_infiltrate
# 0                               0                                    1  \
# 1                               0                                    1
# 2                               0                                    2
# 3                               0                                    3
# 4                               0                                    2
# ..                            ...                                  ...
# 361                             0                                    2
# 362                             0                                    2
# 363                             0                                    2
# 364                             0                                    2
# 365                             0                                    3
#
#      band_like_infiltrate  age  class
# 0                       0   55      2
# 1                       0    8      1
# 2                       3   26      3
# 3                       0   40      1
# 4                       3   45      3
# ..                    ...  ...    ...
# 361                     0   25      4
# 362                     0   36      4
# 363                     3   28      3
# 364                     3   50      3
# 365                     0   35      1
#
# [358 rows x 35 columns]

# %% [markdown]
# ### Convert 'Age' Object to int64

# %%
df['age'] = df['age'].astype('int64')
df['age'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Correlation Analysis

# %%
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize=(30, 30))
ax = sns.heatmap(corr_matrix,
                annot=True,
                linewidths=0.5,
                fmt="0.2f",
                cmap="YlGnBu");

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Preprocessing

# %%
results = {}
model_metrics = {}
models = {
    "LogisticRegression": LogisticRegression(),   
    "KNN": KNeighborsClassifier(),
    "GaussianNB": GaussianNB(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "RandomForestClassifier": RandomForestClassifier(),
    "ExtraTreeClassifier": ExtraTreeClassifier(),
    "SVC": SVC(),
    "MLPClassifier": MLPClassifier(),
    "AdaBoostClassifier": AdaBoostClassifier(),
    "XGBClassifier": xgb.XGBClassifier(),
    "LGBMClassifier": lgbm.LGBMClassifier(),
    "CatBoostClassifier": CatBoostClassifier(),
    "SGDClassifier": SGDClassifier(loss='log'),
    "LinearDiscriminantAnalysis": LinearDiscriminantAnalysis(),
    "QuadraticDiscriminantAnalysis": QuadraticDiscriminantAnalysis()
}

# %%
categorical_transformer = Pipeline(steps=[
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
    ])

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features),
    ])

# %% [markdown]
# ### Split

# %%
X = df.drop("class", axis=1)

le = LabelEncoder()
y = le.fit_transform(df['class'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


# x = df.iloc[:, :-1].values
# y = df.iloc[:, -1].values
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ### Training (Baseline Models)

# %%
# this doesn't work :( 

# import time

# start_training = time.time()
    
# model_pipeline = Pipeline(steps = [
#     ("preprocessor", preprocessor),
#     ("model", LogisticRegression())
# ])

# model_pipeline.fit(X_train, y_train)
# y_preds = model_pipeline.predict(X_test)

# end_training = time.time()
# training_time = end_training - start_training
    
# model_metrics['LogisticRegression'] = [
#     accuracy_score(y_test, y_preds),
#     precision_score(y_test, y_preds, average='weighted'),
#     recall_score(y_test, y_preds, average='weighted'),
#     f1_score(y_test, y_preds, average='weighted'),
#     training_time
# ]

# %% [markdown]
# #### Logistic Regression

# %%
import time
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", LogisticRegression())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['LogisticRegression'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]
# Out:
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# #### KNN

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", KNeighborsClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['KNeighborsClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]

# %% [markdown]
# #### DecisionTreeClassifier

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", DecisionTreeClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['DecisionTreeClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]

# %% [markdown]
# #### RandomForestClassifier

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", RandomForestClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['RandomForestClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]

# %% [markdown]
# #### ExtraTreesClassifier

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", ExtraTreesClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['ExtraTreesClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]

# %% [markdown]
# #### SVM

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", SVC())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['SVC'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]

# %% [markdown]
# #### MLPClassifier

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", MLPClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['MLPClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]
# Out:
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# #### AdaBoost

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", AdaBoostClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['AdaBoostClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]
# Out:
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### XGBoost

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", xgb.XGBClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['XGBClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]

# %% [markdown]
# #### LGBMClassifier

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", lgbm.LGBMClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['LGBMClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]

# %% [markdown]
# #### CatBoostClassifier

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", CatBoostClassifier())
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['CatBoostClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]
# Out:
# Learning rate set to 0.074233
# 0:	learn: 1.6674523	total: 153ms	remaining: 2m 33s
# 1:	learn: 1.4900127	total: 157ms	remaining: 1m 18s
# 2:	learn: 1.3593459	total: 160ms	remaining: 53.2s
# 3:	learn: 1.2546340	total: 163ms	remaining: 40.6s
# 4:	learn: 1.1701582	total: 166ms	remaining: 33s
# 5:	learn: 1.0898960	total: 168ms	remaining: 27.9s
# 6:	learn: 1.0195940	total: 171ms	remaining: 24.2s
# 7:	learn: 0.9552776	total: 173ms	remaining: 21.4s
# 8:	learn: 0.8848579	total: 175ms	remaining: 19.3s
# 9:	learn: 0.8422214	total: 177ms	remaining: 17.6s
# 10:	learn: 0.7888328	total: 180ms	remaining: 16.1s
# 11:	learn: 0.7424752	total: 182ms	remaining: 15s
# 12:	learn: 0.7140321	total: 184ms	remaining: 14s
# 13:	learn: 0.6798897	total: 186ms	remaining: 13.1s
# 14:	learn: 0.6498569	total: 189ms	remaining: 12.4s
# 15:	learn: 0.6190493	total: 191ms	remaining: 11.7s
# 16:	learn: 0.5860832	total: 193ms	remaining: 11.2s
# 17:	learn: 0.5585379	total: 195ms	remaining: 10.7s
# 18:	learn: 0.5333042	total: 197ms	remaining: 10.2s
# 19:	learn: 0.5107678	total: 200ms	remaining: 9.78s
# 20:	learn: 0.4845128	total: 202ms	remaining: 9.4s
# 21:	learn: 0.4638988	total: 204ms	remaining: 9.08s
# 22:	learn: 0.4407076	total: 207ms	remaining: 8.78s
# 23:	learn: 0.4273688	total: 209ms	remaining: 8.49s
# 24:	learn: 0.4093017	total: 211ms	remaining: 8.23s
# 25:	learn: 0.3907706	total: 213ms	remaining: 7.98s
# 26:	learn: 0.3754642	total: 215ms	remaining: 7.76s
# 27:	learn: 0.3639413	total: 217ms	remaining: 7.54s
# 28:	learn: 0.3522342	total: 219ms	remaining: 7.35s
# 29:	learn: 0.3394895	total: 221ms	remaining: 7.16s
# 30:	learn: 0.3287799	total: 223ms	remaining: 6.98s
# 31:	learn: 0.3178053	total: 226ms	remaining: 6.83s
# 32:	learn: 0.3055074	total: 228ms	remaining: 6.68s
# 33:	learn: 0.2973303	total: 230ms	remaining: 6.53s
# 34:	learn: 0.2873632	total: 232ms	remaining: 6.4s
# 35:	learn: 0.2777089	total: 234ms	remaining: 6.27s
# 36:	learn: 0.2690366	total: 236ms	remaining: 6.14s
# 37:	learn: 0.2622606	total: 238ms	remaining: 6.03s
# 38:	learn: 0.2556884	total: 240ms	remaining: 5.91s
# 39:	learn: 0.2501899	total: 242ms	remaining: 5.81s
# 40:	learn: 0.2434919	total: 244ms	remaining: 5.71s
# 41:	learn: 0.2380443	total: 246ms	remaining: 5.62s
# 42:	learn: 0.2311787	total: 248ms	remaining: 5.53s
# 43:	learn: 0.2237335	total: 250ms	remaining: 5.44s
# 44:	learn: 0.2182453	total: 252ms	remaining: 5.35s
# 45:	learn: 0.2123548	total: 255ms	remaining: 5.28s
# 46:	learn: 0.2091514	total: 257ms	remaining: 5.21s
# 47:	learn: 0.2051734	total: 259ms	remaining: 5.14s
# 48:	learn: 0.2002682	total: 261ms	remaining: 5.07s
# 49:	learn: 0.1964742	total: 263ms	remaining: 5s
# 50:	learn: 0.1913877	total: 265ms	remaining: 4.94s
# 51:	learn: 0.1876749	total: 267ms	remaining: 4.87s
# 52:	learn: 0.1833550	total: 270ms	remaining: 4.82s
# 53:	learn: 0.1808380	total: 272ms	remaining: 4.76s
# 54:	learn: 0.1781900	total: 274ms	remaining: 4.7s
# 55:	learn: 0.1746774	total: 276ms	remaining: 4.65s
# 56:	learn: 0.1712894	total: 278ms	remaining: 4.59s
# 57:	learn: 0.1689865	total: 280ms	remaining: 4.54s
# 58:	learn: 0.1645132	total: 282ms	remaining: 4.49s
# 59:	learn: 0.1611077	total: 284ms	remaining: 4.45s
# 60:	learn: 0.1582396	total: 286ms	remaining: 4.4s
# 61:	learn: 0.1563557	total: 288ms	remaining: 4.36s
# 62:	learn: 0.1521787	total: 290ms	remaining: 4.32s
# 63:	learn: 0.1487816	total: 292ms	remaining: 4.28s
# 64:	learn: 0.1454227	total: 294ms	remaining: 4.24s
# 65:	learn: 0.1438824	total: 297ms	remaining: 4.2s
# 66:	learn: 0.1404441	total: 299ms	remaining: 4.16s
# 67:	learn: 0.1378086	total: 301ms	remaining: 4.12s
# 68:	learn: 0.1349283	total: 303ms	remaining: 4.09s
# 69:	learn: 0.1335838	total: 305ms	remaining: 4.05s
# 70:	learn: 0.1314932	total: 307ms	remaining: 4.02s
# 71:	learn: 0.1298274	total: 309ms	remaining: 3.98s
# 72:	learn: 0.1274409	total: 311ms	remaining: 3.95s
# 73:	learn: 0.1260525	total: 313ms	remaining: 3.92s
# 74:	learn: 0.1233348	total: 315ms	remaining: 3.88s
# 75:	learn: 0.1214017	total: 317ms	remaining: 3.85s
# 76:	learn: 0.1190987	total: 320ms	remaining: 3.83s
# 77:	learn: 0.1175136	total: 322ms	remaining: 3.8s
# 78:	learn: 0.1155562	total: 324ms	remaining: 3.77s
# 79:	learn: 0.1138886	total: 326ms	remaining: 3.75s
# 80:	learn: 0.1124655	total: 328ms	remaining: 3.72s
# 81:	learn: 0.1110938	total: 330ms	remaining: 3.69s
# 82:	learn: 0.1085989	total: 332ms	remaining: 3.67s
# 83:	learn: 0.1073256	total: 335ms	remaining: 3.65s
# 84:	learn: 0.1055725	total: 337ms	remaining: 3.62s
# 85:	learn: 0.1045723	total: 339ms	remaining: 3.6s
# 86:	learn: 0.1029338	total: 341ms	remaining: 3.58s
# 87:	learn: 0.1010736	total: 343ms	remaining: 3.55s
# 88:	learn: 0.0991018	total: 345ms	remaining: 3.53s
# 89:	learn: 0.0985369	total: 347ms	remaining: 3.51s
# 90:	learn: 0.0974199	total: 349ms	remaining: 3.49s
# 91:	learn: 0.0964990	total: 351ms	remaining: 3.47s
# 92:	learn: 0.0950027	total: 353ms	remaining: 3.45s
# 93:	learn: 0.0937682	total: 355ms	remaining: 3.43s
# 94:	learn: 0.0926987	total: 358ms	remaining: 3.41s
# 95:	learn: 0.0916655	total: 360ms	remaining: 3.39s
# 96:	learn: 0.0906713	total: 362ms	remaining: 3.37s
# 97:	learn: 0.0891399	total: 364ms	remaining: 3.35s
# 98:	learn: 0.0884757	total: 366ms	remaining: 3.33s
# 99:	learn: 0.0870579	total: 368ms	remaining: 3.31s
# 100:	learn: 0.0859691	total: 370ms	remaining: 3.29s
# 101:	learn: 0.0852768	total: 372ms	remaining: 3.27s
# 102:	learn: 0.0846270	total: 374ms	remaining: 3.26s
# 103:	learn: 0.0839224	total: 376ms	remaining: 3.24s
# 104:	learn: 0.0830737	total: 379ms	remaining: 3.23s
# 105:	learn: 0.0823144	total: 381ms	remaining: 3.21s
# 106:	learn: 0.0815918	total: 383ms	remaining: 3.2s
# 107:	learn: 0.0808479	total: 385ms	remaining: 3.18s
# 108:	learn: 0.0796753	total: 387ms	remaining: 3.16s
# 109:	learn: 0.0788761	total: 389ms	remaining: 3.15s
# 110:	learn: 0.0782798	total: 391ms	remaining: 3.13s
# 111:	learn: 0.0773041	total: 393ms	remaining: 3.12s
# 112:	learn: 0.0766192	total: 395ms	remaining: 3.1s
# 113:	learn: 0.0760152	total: 398ms	remaining: 3.09s
# 114:	learn: 0.0749756	total: 400ms	remaining: 3.08s
# 115:	learn: 0.0744109	total: 402ms	remaining: 3.06s
# 116:	learn: 0.0738043	total: 404ms	remaining: 3.05s
# 117:	learn: 0.0731828	total: 406ms	remaining: 3.03s
# 118:	learn: 0.0724665	total: 408ms	remaining: 3.02s
# 119:	learn: 0.0718022	total: 410ms	remaining: 3.01s
# 120:	learn: 0.0707454	total: 412ms	remaining: 3s
# 121:	learn: 0.0700797	total: 415ms	remaining: 2.98s
# 122:	learn: 0.0689837	total: 417ms	remaining: 2.97s
# 123:	learn: 0.0683922	total: 419ms	remaining: 2.96s
# 124:	learn: 0.0679054	total: 421ms	remaining: 2.94s
# 125:	learn: 0.0673916	total: 423ms	remaining: 2.93s
# 126:	learn: 0.0670730	total: 425ms	remaining: 2.92s
# 127:	learn: 0.0665828	total: 427ms	remaining: 2.91s
# 128:	learn: 0.0661165	total: 429ms	remaining: 2.9s
# 129:	learn: 0.0654818	total: 431ms	remaining: 2.88s
# 130:	learn: 0.0650632	total: 433ms	remaining: 2.87s
# 131:	learn: 0.0645585	total: 435ms	remaining: 2.86s
# 132:	learn: 0.0637657	total: 437ms	remaining: 2.85s
# 133:	learn: 0.0628046	total: 440ms	remaining: 2.84s
# 134:	learn: 0.0622582	total: 442ms	remaining: 2.83s
# 135:	learn: 0.0617557	total: 444ms	remaining: 2.82s
# 136:	learn: 0.0612773	total: 446ms	remaining: 2.81s
# 137:	learn: 0.0608154	total: 448ms	remaining: 2.8s
# 138:	learn: 0.0603706	total: 450ms	remaining: 2.79s
# 139:	learn: 0.0599701	total: 452ms	remaining: 2.77s
# 140:	learn: 0.0595992	total: 454ms	remaining: 2.76s
# 141:	learn: 0.0592141	total: 456ms	remaining: 2.75s
# 142:	learn: 0.0588768	total: 458ms	remaining: 2.75s
# 143:	learn: 0.0583760	total: 460ms	remaining: 2.73s
# 144:	learn: 0.0579715	total: 462ms	remaining: 2.73s
# 145:	learn: 0.0574579	total: 464ms	remaining: 2.71s
# 146:	learn: 0.0571693	total: 466ms	remaining: 2.71s
# 147:	learn: 0.0568536	total: 468ms	remaining: 2.69s
# 148:	learn: 0.0563672	total: 470ms	remaining: 2.68s
# 149:	learn: 0.0561697	total: 472ms	remaining: 2.68s
# 150:	learn: 0.0559177	total: 475ms	remaining: 2.67s
# 151:	learn: 0.0551790	total: 477ms	remaining: 2.66s
# 152:	learn: 0.0548077	total: 479ms	remaining: 2.65s
# 153:	learn: 0.0544259	total: 481ms	remaining: 2.64s
# 154:	learn: 0.0540063	total: 483ms	remaining: 2.63s
# 155:	learn: 0.0534423	total: 485ms	remaining: 2.62s
# 156:	learn: 0.0531676	total: 487ms	remaining: 2.61s
# 157:	learn: 0.0527615	total: 489ms	remaining: 2.61s
# 158:	learn: 0.0522285	total: 491ms	remaining: 2.6s
# 159:	learn: 0.0518187	total: 493ms	remaining: 2.59s
# 160:	learn: 0.0513769	total: 495ms	remaining: 2.58s
# 161:	learn: 0.0509554	total: 497ms	remaining: 2.57s
# 162:	learn: 0.0505311	total: 499ms	remaining: 2.56s
# 163:	learn: 0.0502554	total: 501ms	remaining: 2.55s
# 164:	learn: 0.0499993	total: 503ms	remaining: 2.55s
# 165:	learn: 0.0497011	total: 505ms	remaining: 2.54s
# 166:	learn: 0.0494694	total: 507ms	remaining: 2.53s
# 167:	learn: 0.0491784	total: 509ms	remaining: 2.52s
# 168:	learn: 0.0489320	total: 511ms	remaining: 2.51s
# 169:	learn: 0.0487483	total: 513ms	remaining: 2.5s
# 170:	learn: 0.0483797	total: 515ms	remaining: 2.5s
# 171:	learn: 0.0480199	total: 518ms	remaining: 2.49s
# 172:	learn: 0.0477822	total: 520ms	remaining: 2.48s
# 173:	learn: 0.0475396	total: 522ms	remaining: 2.48s
# 174:	learn: 0.0472215	total: 523ms	remaining: 2.47s
# 175:	learn: 0.0469847	total: 525ms	remaining: 2.46s
# 176:	learn: 0.0467768	total: 527ms	remaining: 2.45s
# 177:	learn: 0.0464346	total: 529ms	remaining: 2.44s
# 178:	learn: 0.0459500	total: 531ms	remaining: 2.44s
# 179:	learn: 0.0454683	total: 533ms	remaining: 2.43s
# 180:	learn: 0.0452173	total: 536ms	remaining: 2.42s
# 181:	learn: 0.0449376	total: 538ms	remaining: 2.42s
# 182:	learn: 0.0447614	total: 540ms	remaining: 2.41s
# 183:	learn: 0.0444548	total: 541ms	remaining: 2.4s
# 184:	learn: 0.0441695	total: 543ms	remaining: 2.39s
# 185:	learn: 0.0439762	total: 545ms	remaining: 2.39s
# 186:	learn: 0.0437249	total: 548ms	remaining: 2.38s
# 187:	learn: 0.0435452	total: 550ms	remaining: 2.37s
# 188:	learn: 0.0433025	total: 551ms	remaining: 2.37s
# 189:	learn: 0.0429865	total: 554ms	remaining: 2.36s
# 190:	learn: 0.0426589	total: 555ms	remaining: 2.35s
# 191:	learn: 0.0424728	total: 557ms	remaining: 2.35s
# 192:	learn: 0.0422609	total: 559ms	remaining: 2.34s
# 193:	learn: 0.0417957	total: 561ms	remaining: 2.33s
# 194:	learn: 0.0415963	total: 564ms	remaining: 2.33s
# 195:	learn: 0.0414015	total: 566ms	remaining: 2.32s
# 196:	learn: 0.0412266	total: 568ms	remaining: 2.31s
# 197:	learn: 0.0409427	total: 570ms	remaining: 2.31s
# 198:	learn: 0.0406790	total: 572ms	remaining: 2.3s
# 199:	learn: 0.0404934	total: 574ms	remaining: 2.29s
# 200:	learn: 0.0401594	total: 576ms	remaining: 2.29s
# 201:	learn: 0.0398831	total: 578ms	remaining: 2.28s
# 202:	learn: 0.0396461	total: 580ms	remaining: 2.28s
# 203:	learn: 0.0394833	total: 582ms	remaining: 2.27s
# 204:	learn: 0.0393356	total: 584ms	remaining: 2.27s
# 205:	learn: 0.0391214	total: 586ms	remaining: 2.26s
# 206:	learn: 0.0389882	total: 588ms	remaining: 2.25s
# 207:	learn: 0.0388604	total: 590ms	remaining: 2.25s
# 208:	learn: 0.0387199	total: 592ms	remaining: 2.24s
# 209:	learn: 0.0385846	total: 595ms	remaining: 2.24s
# 210:	learn: 0.0384413	total: 597ms	remaining: 2.23s
# 211:	learn: 0.0383045	total: 599ms	remaining: 2.23s
# 212:	learn: 0.0381501	total: 601ms	remaining: 2.22s
# 213:	learn: 0.0379652	total: 603ms	remaining: 2.21s
# 214:	learn: 0.0377978	total: 605ms	remaining: 2.21s
# 215:	learn: 0.0375619	total: 607ms	remaining: 2.2s
# 216:	learn: 0.0372556	total: 609ms	remaining: 2.2s
# 217:	learn: 0.0371198	total: 611ms	remaining: 2.19s
# 218:	learn: 0.0367993	total: 621ms	remaining: 2.21s
# 219:	learn: 0.0366314	total: 623ms	remaining: 2.21s
# 220:	learn: 0.0364695	total: 625ms	remaining: 2.2s
# 221:	learn: 0.0362650	total: 627ms	remaining: 2.2s
# 222:	learn: 0.0360559	total: 629ms	remaining: 2.19s
# 223:	learn: 0.0359162	total: 631ms	remaining: 2.19s
# 224:	learn: 0.0358286	total: 633ms	remaining: 2.18s
# 225:	learn: 0.0356965	total: 635ms	remaining: 2.17s
# 226:	learn: 0.0355517	total: 637ms	remaining: 2.17s
# 227:	learn: 0.0352879	total: 639ms	remaining: 2.16s
# 228:	learn: 0.0351429	total: 641ms	remaining: 2.16s
# 229:	learn: 0.0348919	total: 643ms	remaining: 2.15s
# 230:	learn: 0.0347378	total: 645ms	remaining: 2.15s
# 231:	learn: 0.0345239	total: 647ms	remaining: 2.14s
# 232:	learn: 0.0343684	total: 649ms	remaining: 2.14s
# 233:	learn: 0.0342152	total: 651ms	remaining: 2.13s
# 234:	learn: 0.0340622	total: 653ms	remaining: 2.13s
# 235:	learn: 0.0338919	total: 655ms	remaining: 2.12s
# 236:	learn: 0.0337009	total: 657ms	remaining: 2.12s
# 237:	learn: 0.0335036	total: 659ms	remaining: 2.11s
# 238:	learn: 0.0332738	total: 661ms	remaining: 2.11s
# 239:	learn: 0.0331841	total: 664ms	remaining: 2.1s
# 240:	learn: 0.0331062	total: 666ms	remaining: 2.1s
# 241:	learn: 0.0329521	total: 668ms	remaining: 2.09s
# 242:	learn: 0.0327265	total: 670ms	remaining: 2.08s
# 243:	learn: 0.0326256	total: 672ms	remaining: 2.08s
# 244:	learn: 0.0325303	total: 674ms	remaining: 2.08s
# 245:	learn: 0.0323725	total: 676ms	remaining: 2.07s
# 246:	learn: 0.0322497	total: 678ms	remaining: 2.06s
# 247:	learn: 0.0321670	total: 680ms	remaining: 2.06s
# 248:	learn: 0.0320531	total: 682ms	remaining: 2.06s
# 249:	learn: 0.0319509	total: 684ms	remaining: 2.05s
# 250:	learn: 0.0317962	total: 685ms	remaining: 2.04s
# 251:	learn: 0.0316793	total: 687ms	remaining: 2.04s
# 252:	learn: 0.0314738	total: 689ms	remaining: 2.04s
# 253:	learn: 0.0313509	total: 691ms	remaining: 2.03s
# 254:	learn: 0.0312128	total: 693ms	remaining: 2.03s
# 255:	learn: 0.0310590	total: 695ms	remaining: 2.02s
# 256:	learn: 0.0308941	total: 697ms	remaining: 2.02s
# 257:	learn: 0.0307403	total: 699ms	remaining: 2.01s
# 258:	learn: 0.0305257	total: 701ms	remaining: 2.01s
# 259:	learn: 0.0304149	total: 703ms	remaining: 2s
# 260:	learn: 0.0302565	total: 705ms	remaining: 2s
# 261:	learn: 0.0300649	total: 707ms	remaining: 1.99s
# 262:	learn: 0.0299277	total: 709ms	remaining: 1.99s
# 263:	learn: 0.0297725	total: 711ms	remaining: 1.98s
# 264:	learn: 0.0295878	total: 713ms	remaining: 1.98s
# 265:	learn: 0.0294702	total: 715ms	remaining: 1.97s
# 266:	learn: 0.0293273	total: 717ms	remaining: 1.97s
# 267:	learn: 0.0292072	total: 719ms	remaining: 1.96s
# 268:	learn: 0.0291063	total: 721ms	remaining: 1.96s
# 269:	learn: 0.0289496	total: 723ms	remaining: 1.96s
# 270:	learn: 0.0288062	total: 725ms	remaining: 1.95s
# 271:	learn: 0.0286705	total: 727ms	remaining: 1.95s
# 272:	learn: 0.0286000	total: 729ms	remaining: 1.94s
# 273:	learn: 0.0285218	total: 731ms	remaining: 1.94s
# 274:	learn: 0.0284176	total: 733ms	remaining: 1.93s
# 275:	learn: 0.0283319	total: 735ms	remaining: 1.93s
# 276:	learn: 0.0282511	total: 737ms	remaining: 1.92s
# 277:	learn: 0.0280958	total: 739ms	remaining: 1.92s
# 278:	learn: 0.0280037	total: 741ms	remaining: 1.91s
# 279:	learn: 0.0278542	total: 743ms	remaining: 1.91s
# 280:	learn: 0.0277437	total: 745ms	remaining: 1.91s
# 281:	learn: 0.0276537	total: 747ms	remaining: 1.9s
# 282:	learn: 0.0274642	total: 749ms	remaining: 1.9s
# 283:	learn: 0.0273776	total: 751ms	remaining: 1.89s
# 284:	learn: 0.0272689	total: 753ms	remaining: 1.89s
# 285:	learn: 0.0272160	total: 755ms	remaining: 1.89s
# 286:	learn: 0.0269864	total: 757ms	remaining: 1.88s
# 287:	learn: 0.0268955	total: 759ms	remaining: 1.88s
# 288:	learn: 0.0268059	total: 761ms	remaining: 1.87s
# 289:	learn: 0.0267025	total: 763ms	remaining: 1.87s
# 290:	learn: 0.0266127	total: 765ms	remaining: 1.86s
# 291:	learn: 0.0265171	total: 767ms	remaining: 1.86s
# 292:	learn: 0.0264571	total: 769ms	remaining: 1.85s
# 293:	learn: 0.0263466	total: 771ms	remaining: 1.85s
# 294:	learn: 0.0262362	total: 773ms	remaining: 1.85s
# 295:	learn: 0.0261563	total: 775ms	remaining: 1.84s
# 296:	learn: 0.0260821	total: 777ms	remaining: 1.84s
# 297:	learn: 0.0260205	total: 778ms	remaining: 1.83s
# 298:	learn: 0.0259181	total: 780ms	remaining: 1.83s
# 299:	learn: 0.0258023	total: 782ms	remaining: 1.82s
# 300:	learn: 0.0256907	total: 785ms	remaining: 1.82s
# 301:	learn: 0.0255887	total: 787ms	remaining: 1.82s
# 302:	learn: 0.0254784	total: 789ms	remaining: 1.81s
# 303:	learn: 0.0254076	total: 791ms	remaining: 1.81s
# 304:	learn: 0.0253355	total: 793ms	remaining: 1.81s
# 305:	learn: 0.0252402	total: 795ms	remaining: 1.8s
# 306:	learn: 0.0251337	total: 797ms	remaining: 1.8s
# 307:	learn: 0.0250601	total: 799ms	remaining: 1.79s
# 308:	learn: 0.0249991	total: 801ms	remaining: 1.79s
# 309:	learn: 0.0249348	total: 803ms	remaining: 1.79s
# 310:	learn: 0.0248199	total: 805ms	remaining: 1.78s
# 311:	learn: 0.0247205	total: 807ms	remaining: 1.78s
# 312:	learn: 0.0246564	total: 809ms	remaining: 1.77s
# 313:	learn: 0.0245749	total: 811ms	remaining: 1.77s
# 314:	learn: 0.0244886	total: 813ms	remaining: 1.77s
# 315:	learn: 0.0243796	total: 816ms	remaining: 1.76s
# 316:	learn: 0.0242941	total: 817ms	remaining: 1.76s
# 317:	learn: 0.0242554	total: 819ms	remaining: 1.76s
# 318:	learn: 0.0241761	total: 822ms	remaining: 1.75s
# 319:	learn: 0.0241223	total: 824ms	remaining: 1.75s
# 320:	learn: 0.0240316	total: 826ms	remaining: 1.75s
# 321:	learn: 0.0239663	total: 828ms	remaining: 1.74s
# 322:	learn: 0.0237700	total: 830ms	remaining: 1.74s
# 323:	learn: 0.0237330	total: 832ms	remaining: 1.74s
# 324:	learn: 0.0236330	total: 834ms	remaining: 1.73s
# 325:	learn: 0.0235557	total: 836ms	remaining: 1.73s
# 326:	learn: 0.0234838	total: 838ms	remaining: 1.73s
# 327:	learn: 0.0233781	total: 840ms	remaining: 1.72s
# 328:	learn: 0.0232122	total: 843ms	remaining: 1.72s
# 329:	learn: 0.0230847	total: 845ms	remaining: 1.72s
# 330:	learn: 0.0229917	total: 847ms	remaining: 1.71s
# 331:	learn: 0.0229360	total: 849ms	remaining: 1.71s
# 332:	learn: 0.0228464	total: 851ms	remaining: 1.7s
# 333:	learn: 0.0227909	total: 853ms	remaining: 1.7s
# 334:	learn: 0.0227413	total: 855ms	remaining: 1.7s
# 335:	learn: 0.0226760	total: 857ms	remaining: 1.69s
# 336:	learn: 0.0226145	total: 859ms	remaining: 1.69s
# 337:	learn: 0.0225430	total: 861ms	remaining: 1.69s
# 338:	learn: 0.0224645	total: 863ms	remaining: 1.68s
# 339:	learn: 0.0223873	total: 865ms	remaining: 1.68s
# 340:	learn: 0.0222831	total: 867ms	remaining: 1.68s
# 341:	learn: 0.0222235	total: 869ms	remaining: 1.67s
# 342:	learn: 0.0221550	total: 871ms	remaining: 1.67s
# 343:	learn: 0.0220169	total: 874ms	remaining: 1.67s
# 344:	learn: 0.0219639	total: 876ms	remaining: 1.66s
# 345:	learn: 0.0218758	total: 878ms	remaining: 1.66s
# 346:	learn: 0.0218291	total: 880ms	remaining: 1.66s
# 347:	learn: 0.0217743	total: 882ms	remaining: 1.65s
# 348:	learn: 0.0217145	total: 884ms	remaining: 1.65s
# 349:	learn: 0.0216291	total: 886ms	remaining: 1.64s
# 350:	learn: 0.0214848	total: 888ms	remaining: 1.64s
# 351:	learn: 0.0214151	total: 890ms	remaining: 1.64s
# 352:	learn: 0.0213611	total: 892ms	remaining: 1.63s
# 353:	learn: 0.0212782	total: 894ms	remaining: 1.63s
# 354:	learn: 0.0211381	total: 896ms	remaining: 1.63s
# 355:	learn: 0.0210726	total: 898ms	remaining: 1.62s
# 356:	learn: 0.0210317	total: 900ms	remaining: 1.62s
# 357:	learn: 0.0209860	total: 902ms	remaining: 1.62s
# 358:	learn: 0.0208763	total: 904ms	remaining: 1.61s
# 359:	learn: 0.0208156	total: 906ms	remaining: 1.61s
# 360:	learn: 0.0207771	total: 908ms	remaining: 1.61s
# 361:	learn: 0.0207137	total: 910ms	remaining: 1.6s
# 362:	learn: 0.0206782	total: 912ms	remaining: 1.6s
# 363:	learn: 0.0206411	total: 914ms	remaining: 1.6s
# 364:	learn: 0.0205965	total: 916ms	remaining: 1.59s
# 365:	learn: 0.0205566	total: 918ms	remaining: 1.59s
# 366:	learn: 0.0204950	total: 920ms	remaining: 1.59s
# 367:	learn: 0.0204566	total: 922ms	remaining: 1.58s
# 368:	learn: 0.0204293	total: 924ms	remaining: 1.58s
# 369:	learn: 0.0203696	total: 926ms	remaining: 1.58s
# 370:	learn: 0.0203203	total: 928ms	remaining: 1.57s
# 371:	learn: 0.0202554	total: 930ms	remaining: 1.57s
# 372:	learn: 0.0202076	total: 932ms	remaining: 1.57s
# 373:	learn: 0.0201250	total: 934ms	remaining: 1.56s
# 374:	learn: 0.0200744	total: 936ms	remaining: 1.56s
# 375:	learn: 0.0200011	total: 938ms	remaining: 1.56s
# 376:	learn: 0.0199253	total: 940ms	remaining: 1.55s
# 377:	learn: 0.0198628	total: 942ms	remaining: 1.55s
# 378:	learn: 0.0197905	total: 944ms	remaining: 1.55s
# 379:	learn: 0.0197405	total: 946ms	remaining: 1.54s
# 380:	learn: 0.0196649	total: 948ms	remaining: 1.54s
# 381:	learn: 0.0196024	total: 950ms	remaining: 1.54s
# 382:	learn: 0.0195478	total: 952ms	remaining: 1.53s
# 383:	learn: 0.0194994	total: 954ms	remaining: 1.53s
# 384:	learn: 0.0194182	total: 956ms	remaining: 1.53s
# 385:	learn: 0.0193500	total: 958ms	remaining: 1.52s
# 386:	learn: 0.0192907	total: 960ms	remaining: 1.52s
# 387:	learn: 0.0192554	total: 962ms	remaining: 1.52s
# 388:	learn: 0.0191753	total: 964ms	remaining: 1.51s
# 389:	learn: 0.0191233	total: 967ms	remaining: 1.51s
# 390:	learn: 0.0190562	total: 969ms	remaining: 1.51s
# 391:	learn: 0.0189805	total: 971ms	remaining: 1.5s
# 392:	learn: 0.0189389	total: 973ms	remaining: 1.5s
# 393:	learn: 0.0188984	total: 975ms	remaining: 1.5s
# 394:	learn: 0.0188068	total: 977ms	remaining: 1.5s
# 395:	learn: 0.0186964	total: 979ms	remaining: 1.49s
# 396:	learn: 0.0186645	total: 981ms	remaining: 1.49s
# 397:	learn: 0.0185536	total: 984ms	remaining: 1.49s
# 398:	learn: 0.0185116	total: 986ms	remaining: 1.48s
# 399:	learn: 0.0184506	total: 988ms	remaining: 1.48s
# 400:	learn: 0.0184105	total: 990ms	remaining: 1.48s
# 401:	learn: 0.0183625	total: 992ms	remaining: 1.48s
# 402:	learn: 0.0183191	total: 994ms	remaining: 1.47s
# 403:	learn: 0.0182764	total: 996ms	remaining: 1.47s
# 404:	learn: 0.0182382	total: 998ms	remaining: 1.47s
# 405:	learn: 0.0181910	total: 1s	remaining: 1.46s
# 406:	learn: 0.0181557	total: 1s	remaining: 1.46s
# 407:	learn: 0.0181106	total: 1s	remaining: 1.46s
# 408:	learn: 0.0180677	total: 1.01s	remaining: 1.45s
# 409:	learn: 0.0180211	total: 1.01s	remaining: 1.45s
# 410:	learn: 0.0179346	total: 1.01s	remaining: 1.45s
# 411:	learn: 0.0178838	total: 1.01s	remaining: 1.45s
# 412:	learn: 0.0178632	total: 1.01s	remaining: 1.44s
# 413:	learn: 0.0177714	total: 1.02s	remaining: 1.44s
# 414:	learn: 0.0177111	total: 1.02s	remaining: 1.44s
# 415:	learn: 0.0176310	total: 1.02s	remaining: 1.43s
# 416:	learn: 0.0175676	total: 1.02s	remaining: 1.43s
# 417:	learn: 0.0175379	total: 1.02s	remaining: 1.43s
# 418:	learn: 0.0175090	total: 1.03s	remaining: 1.42s
# 419:	learn: 0.0174612	total: 1.03s	remaining: 1.42s
# 420:	learn: 0.0174225	total: 1.03s	remaining: 1.42s
# 421:	learn: 0.0173821	total: 1.03s	remaining: 1.42s
# 422:	learn: 0.0173460	total: 1.03s	remaining: 1.41s
# 423:	learn: 0.0172990	total: 1.04s	remaining: 1.41s
# 424:	learn: 0.0172725	total: 1.04s	remaining: 1.41s
# 425:	learn: 0.0172159	total: 1.04s	remaining: 1.4s
# 426:	learn: 0.0171655	total: 1.04s	remaining: 1.4s
# 427:	learn: 0.0171338	total: 1.04s	remaining: 1.4s
# 428:	learn: 0.0170436	total: 1.05s	remaining: 1.39s
# 429:	learn: 0.0170219	total: 1.05s	remaining: 1.39s
# 430:	learn: 0.0169827	total: 1.05s	remaining: 1.39s
# 431:	learn: 0.0169389	total: 1.05s	remaining: 1.38s
# 432:	learn: 0.0168895	total: 1.05s	remaining: 1.38s
# 433:	learn: 0.0168516	total: 1.06s	remaining: 1.38s
# 434:	learn: 0.0168151	total: 1.06s	remaining: 1.38s
# 435:	learn: 0.0167880	total: 1.06s	remaining: 1.37s
# 436:	learn: 0.0167533	total: 1.06s	remaining: 1.37s
# 437:	learn: 0.0167120	total: 1.06s	remaining: 1.37s
# 438:	learn: 0.0166652	total: 1.07s	remaining: 1.36s
# 439:	learn: 0.0165834	total: 1.07s	remaining: 1.36s
# 440:	learn: 0.0165464	total: 1.07s	remaining: 1.36s
# 441:	learn: 0.0165040	total: 1.07s	remaining: 1.35s
# 442:	learn: 0.0164758	total: 1.07s	remaining: 1.35s
# 443:	learn: 0.0164422	total: 1.08s	remaining: 1.35s
# 444:	learn: 0.0164088	total: 1.08s	remaining: 1.35s
# 445:	learn: 0.0163711	total: 1.08s	remaining: 1.34s
# 446:	learn: 0.0163340	total: 1.08s	remaining: 1.34s
# 447:	learn: 0.0163029	total: 1.08s	remaining: 1.34s
# 448:	learn: 0.0162626	total: 1.09s	remaining: 1.33s
# 449:	learn: 0.0162367	total: 1.09s	remaining: 1.33s
# 450:	learn: 0.0162064	total: 1.09s	remaining: 1.33s
# 451:	learn: 0.0161810	total: 1.09s	remaining: 1.32s
# 452:	learn: 0.0161269	total: 1.09s	remaining: 1.32s
# 453:	learn: 0.0160981	total: 1.1s	remaining: 1.32s
# 454:	learn: 0.0160459	total: 1.1s	remaining: 1.32s
# 455:	learn: 0.0160227	total: 1.1s	remaining: 1.31s
# 456:	learn: 0.0159748	total: 1.1s	remaining: 1.31s
# 457:	learn: 0.0159376	total: 1.1s	remaining: 1.31s
# 458:	learn: 0.0158820	total: 1.11s	remaining: 1.3s
# 459:	learn: 0.0158500	total: 1.11s	remaining: 1.3s
# 460:	learn: 0.0158249	total: 1.11s	remaining: 1.3s
# 461:	learn: 0.0157938	total: 1.11s	remaining: 1.3s
# 462:	learn: 0.0157658	total: 1.11s	remaining: 1.29s
# 463:	learn: 0.0157261	total: 1.12s	remaining: 1.29s
# 464:	learn: 0.0156980	total: 1.12s	remaining: 1.29s
# 465:	learn: 0.0156754	total: 1.12s	remaining: 1.28s
# 466:	learn: 0.0156331	total: 1.12s	remaining: 1.28s
# 467:	learn: 0.0155826	total: 1.13s	remaining: 1.28s
# 468:	learn: 0.0155427	total: 1.13s	remaining: 1.28s
# 469:	learn: 0.0155009	total: 1.13s	remaining: 1.27s
# 470:	learn: 0.0154579	total: 1.13s	remaining: 1.27s
# 471:	learn: 0.0154300	total: 1.13s	remaining: 1.27s
# 472:	learn: 0.0154044	total: 1.14s	remaining: 1.27s
# 473:	learn: 0.0153630	total: 1.14s	remaining: 1.26s
# 474:	learn: 0.0153420	total: 1.14s	remaining: 1.26s
# 475:	learn: 0.0152789	total: 1.14s	remaining: 1.26s
# 476:	learn: 0.0152502	total: 1.14s	remaining: 1.25s
# 477:	learn: 0.0152067	total: 1.15s	remaining: 1.25s
# 478:	learn: 0.0151283	total: 1.15s	remaining: 1.25s
# 479:	learn: 0.0150990	total: 1.15s	remaining: 1.25s
# 480:	learn: 0.0150685	total: 1.15s	remaining: 1.24s
# 481:	learn: 0.0150359	total: 1.15s	remaining: 1.24s
# 482:	learn: 0.0150109	total: 1.16s	remaining: 1.24s
# 483:	learn: 0.0149921	total: 1.16s	remaining: 1.24s
# 484:	learn: 0.0149565	total: 1.16s	remaining: 1.23s
# 485:	learn: 0.0148816	total: 1.16s	remaining: 1.23s
# 486:	learn: 0.0148258	total: 1.17s	remaining: 1.23s
# 487:	learn: 0.0148002	total: 1.17s	remaining: 1.23s
# 488:	learn: 0.0147673	total: 1.17s	remaining: 1.22s
# 489:	learn: 0.0147420	total: 1.17s	remaining: 1.22s
# 490:	learn: 0.0147181	total: 1.17s	remaining: 1.22s
# 491:	learn: 0.0146937	total: 1.18s	remaining: 1.22s
# 492:	learn: 0.0146602	total: 1.18s	remaining: 1.21s
# 493:	learn: 0.0146120	total: 1.18s	remaining: 1.21s
# 494:	learn: 0.0145887	total: 1.18s	remaining: 1.21s
# 495:	learn: 0.0145614	total: 1.19s	remaining: 1.2s
# 496:	learn: 0.0145361	total: 1.19s	remaining: 1.2s
# 497:	learn: 0.0145029	total: 1.19s	remaining: 1.2s
# 498:	learn: 0.0144541	total: 1.19s	remaining: 1.2s
# 499:	learn: 0.0144254	total: 1.19s	remaining: 1.19s
# 500:	learn: 0.0143756	total: 1.2s	remaining: 1.19s
# 501:	learn: 0.0143490	total: 1.2s	remaining: 1.19s
# 502:	learn: 0.0143168	total: 1.2s	remaining: 1.19s
# 503:	learn: 0.0142958	total: 1.2s	remaining: 1.18s
# 504:	learn: 0.0142589	total: 1.21s	remaining: 1.18s
# 505:	learn: 0.0142304	total: 1.21s	remaining: 1.18s
# 506:	learn: 0.0142099	total: 1.21s	remaining: 1.18s
# 507:	learn: 0.0141745	total: 1.21s	remaining: 1.17s
# 508:	learn: 0.0141557	total: 1.21s	remaining: 1.17s
# 509:	learn: 0.0141030	total: 1.22s	remaining: 1.17s
# 510:	learn: 0.0140804	total: 1.22s	remaining: 1.17s
# 511:	learn: 0.0140615	total: 1.22s	remaining: 1.16s
# 512:	learn: 0.0140387	total: 1.22s	remaining: 1.16s
# 513:	learn: 0.0140131	total: 1.22s	remaining: 1.16s
# 514:	learn: 0.0139795	total: 1.23s	remaining: 1.16s
# 515:	learn: 0.0139161	total: 1.23s	remaining: 1.15s
# 516:	learn: 0.0138935	total: 1.23s	remaining: 1.15s
# 517:	learn: 0.0138648	total: 1.23s	remaining: 1.15s
# 518:	learn: 0.0138416	total: 1.24s	remaining: 1.14s
# 519:	learn: 0.0137994	total: 1.24s	remaining: 1.14s
# 520:	learn: 0.0137732	total: 1.24s	remaining: 1.14s
# 521:	learn: 0.0137416	total: 1.24s	remaining: 1.14s
# 522:	learn: 0.0136812	total: 1.24s	remaining: 1.13s
# 523:	learn: 0.0136140	total: 1.25s	remaining: 1.13s
# 524:	learn: 0.0135985	total: 1.25s	remaining: 1.13s
# 525:	learn: 0.0135772	total: 1.25s	remaining: 1.13s
# 526:	learn: 0.0135512	total: 1.25s	remaining: 1.12s
# 527:	learn: 0.0135261	total: 1.25s	remaining: 1.12s
# 528:	learn: 0.0134832	total: 1.26s	remaining: 1.12s
# 529:	learn: 0.0134499	total: 1.26s	remaining: 1.12s
# 530:	learn: 0.0134231	total: 1.26s	remaining: 1.11s
# 531:	learn: 0.0133750	total: 1.26s	remaining: 1.11s
# 532:	learn: 0.0133514	total: 1.26s	remaining: 1.11s
# 533:	learn: 0.0133006	total: 1.27s	remaining: 1.1s
# 534:	learn: 0.0132559	total: 1.27s	remaining: 1.1s
# 535:	learn: 0.0132270	total: 1.27s	remaining: 1.1s
# 536:	learn: 0.0132065	total: 1.27s	remaining: 1.1s
# 537:	learn: 0.0131864	total: 1.27s	remaining: 1.09s
# 538:	learn: 0.0131624	total: 1.28s	remaining: 1.09s
# 539:	learn: 0.0131458	total: 1.28s	remaining: 1.09s
# 540:	learn: 0.0130934	total: 1.28s	remaining: 1.09s
# 541:	learn: 0.0130469	total: 1.28s	remaining: 1.08s
# 542:	learn: 0.0130226	total: 1.28s	remaining: 1.08s
# 543:	learn: 0.0129947	total: 1.29s	remaining: 1.08s
# 544:	learn: 0.0129812	total: 1.29s	remaining: 1.08s
# 545:	learn: 0.0129486	total: 1.29s	remaining: 1.07s
# 546:	learn: 0.0129330	total: 1.29s	remaining: 1.07s
# 547:	learn: 0.0128968	total: 1.3s	remaining: 1.07s
# 548:	learn: 0.0128779	total: 1.3s	remaining: 1.07s
# 549:	learn: 0.0128418	total: 1.3s	remaining: 1.06s
# 550:	learn: 0.0128088	total: 1.3s	remaining: 1.06s
# 551:	learn: 0.0127827	total: 1.3s	remaining: 1.06s
# 552:	learn: 0.0127618	total: 1.31s	remaining: 1.06s
# 553:	learn: 0.0127401	total: 1.31s	remaining: 1.05s
# 554:	learn: 0.0127141	total: 1.31s	remaining: 1.05s
# 555:	learn: 0.0126787	total: 1.31s	remaining: 1.05s
# 556:	learn: 0.0126453	total: 1.31s	remaining: 1.05s
# 557:	learn: 0.0126153	total: 1.32s	remaining: 1.04s
# 558:	learn: 0.0125990	total: 1.32s	remaining: 1.04s
# 559:	learn: 0.0125708	total: 1.32s	remaining: 1.04s
# 560:	learn: 0.0125494	total: 1.32s	remaining: 1.04s
# 561:	learn: 0.0124968	total: 1.33s	remaining: 1.03s
# 562:	learn: 0.0124664	total: 1.33s	remaining: 1.03s
# 563:	learn: 0.0124417	total: 1.33s	remaining: 1.03s
# 564:	learn: 0.0124175	total: 1.33s	remaining: 1.02s
# 565:	learn: 0.0123992	total: 1.33s	remaining: 1.02s
# 566:	learn: 0.0123799	total: 1.34s	remaining: 1.02s
# 567:	learn: 0.0123631	total: 1.34s	remaining: 1.02s
# 568:	learn: 0.0123397	total: 1.34s	remaining: 1.01s
# 569:	learn: 0.0123297	total: 1.34s	remaining: 1.01s
# 570:	learn: 0.0123075	total: 1.34s	remaining: 1.01s
# 571:	learn: 0.0122914	total: 1.35s	remaining: 1.01s
# 572:	learn: 0.0122731	total: 1.35s	remaining: 1s
# 573:	learn: 0.0122457	total: 1.35s	remaining: 1s
# 574:	learn: 0.0122087	total: 1.35s	remaining: 1s
# 575:	learn: 0.0121961	total: 1.36s	remaining: 999ms
# 576:	learn: 0.0121793	total: 1.36s	remaining: 996ms
# 577:	learn: 0.0121595	total: 1.36s	remaining: 994ms
# 578:	learn: 0.0121381	total: 1.36s	remaining: 991ms
# 579:	learn: 0.0121202	total: 1.36s	remaining: 989ms
# 580:	learn: 0.0120993	total: 1.37s	remaining: 986ms
# 581:	learn: 0.0120563	total: 1.37s	remaining: 984ms
# 582:	learn: 0.0120242	total: 1.37s	remaining: 982ms
# 583:	learn: 0.0120087	total: 1.37s	remaining: 979ms
# 584:	learn: 0.0119854	total: 1.38s	remaining: 977ms
# 585:	learn: 0.0119616	total: 1.38s	remaining: 974ms
# 586:	learn: 0.0119098	total: 1.38s	remaining: 972ms
# 587:	learn: 0.0118963	total: 1.38s	remaining: 969ms
# 588:	learn: 0.0118781	total: 1.39s	remaining: 967ms
# 589:	learn: 0.0118655	total: 1.39s	remaining: 964ms
# 590:	learn: 0.0118521	total: 1.39s	remaining: 961ms
# 591:	learn: 0.0118364	total: 1.39s	remaining: 959ms
# 592:	learn: 0.0117814	total: 1.39s	remaining: 956ms
# 593:	learn: 0.0117639	total: 1.4s	remaining: 954ms
# 594:	learn: 0.0117408	total: 1.4s	remaining: 951ms
# 595:	learn: 0.0117185	total: 1.4s	remaining: 949ms
# 596:	learn: 0.0116920	total: 1.4s	remaining: 946ms
# 597:	learn: 0.0116675	total: 1.4s	remaining: 944ms
# 598:	learn: 0.0116523	total: 1.41s	remaining: 941ms
# 599:	learn: 0.0116330	total: 1.41s	remaining: 939ms
# 600:	learn: 0.0116128	total: 1.41s	remaining: 936ms
# 601:	learn: 0.0115833	total: 1.41s	remaining: 934ms
# 602:	learn: 0.0115671	total: 1.41s	remaining: 931ms
# 603:	learn: 0.0115555	total: 1.42s	remaining: 929ms
# 604:	learn: 0.0115396	total: 1.42s	remaining: 926ms
# 605:	learn: 0.0115035	total: 1.42s	remaining: 924ms
# 606:	learn: 0.0114881	total: 1.42s	remaining: 921ms
# 607:	learn: 0.0114715	total: 1.42s	remaining: 919ms
# 608:	learn: 0.0114598	total: 1.43s	remaining: 916ms
# 609:	learn: 0.0114339	total: 1.43s	remaining: 914ms
# 610:	learn: 0.0114085	total: 1.43s	remaining: 911ms
# 611:	learn: 0.0113598	total: 1.43s	remaining: 909ms
# 612:	learn: 0.0113412	total: 1.44s	remaining: 906ms
# 613:	learn: 0.0113299	total: 1.44s	remaining: 904ms
# 614:	learn: 0.0113165	total: 1.44s	remaining: 901ms
# 615:	learn: 0.0113023	total: 1.44s	remaining: 899ms
# 616:	learn: 0.0112719	total: 1.44s	remaining: 896ms
# 617:	learn: 0.0112525	total: 1.45s	remaining: 894ms
# 618:	learn: 0.0112349	total: 1.45s	remaining: 891ms
# 619:	learn: 0.0112168	total: 1.45s	remaining: 889ms
# 620:	learn: 0.0111917	total: 1.45s	remaining: 886ms
# 621:	learn: 0.0111715	total: 1.45s	remaining: 884ms
# 622:	learn: 0.0111482	total: 1.46s	remaining: 881ms
# 623:	learn: 0.0111304	total: 1.46s	remaining: 879ms
# 624:	learn: 0.0111171	total: 1.46s	remaining: 876ms
# 625:	learn: 0.0110938	total: 1.46s	remaining: 874ms
# 626:	learn: 0.0110771	total: 1.46s	remaining: 871ms
# 627:	learn: 0.0110617	total: 1.47s	remaining: 869ms
# 628:	learn: 0.0110400	total: 1.47s	remaining: 867ms
# 629:	learn: 0.0110235	total: 1.47s	remaining: 864ms
# 630:	learn: 0.0110125	total: 1.47s	remaining: 862ms
# 631:	learn: 0.0109996	total: 1.48s	remaining: 859ms
# 632:	learn: 0.0109755	total: 1.48s	remaining: 857ms
# 633:	learn: 0.0109583	total: 1.48s	remaining: 854ms
# 634:	learn: 0.0109354	total: 1.48s	remaining: 852ms
# 635:	learn: 0.0109200	total: 1.48s	remaining: 849ms
# 636:	learn: 0.0109010	total: 1.49s	remaining: 847ms
# 637:	learn: 0.0108773	total: 1.49s	remaining: 844ms
# 638:	learn: 0.0108559	total: 1.49s	remaining: 842ms
# 639:	learn: 0.0108334	total: 1.49s	remaining: 839ms
# 640:	learn: 0.0108232	total: 1.49s	remaining: 837ms
# 641:	learn: 0.0108113	total: 1.5s	remaining: 835ms
# 642:	learn: 0.0107970	total: 1.5s	remaining: 832ms
# 643:	learn: 0.0107714	total: 1.5s	remaining: 830ms
# 644:	learn: 0.0107419	total: 1.5s	remaining: 827ms
# 645:	learn: 0.0107191	total: 1.5s	remaining: 825ms
# 646:	learn: 0.0106977	total: 1.51s	remaining: 822ms
# 647:	learn: 0.0106853	total: 1.51s	remaining: 820ms
# 648:	learn: 0.0106715	total: 1.51s	remaining: 817ms
# 649:	learn: 0.0106472	total: 1.51s	remaining: 815ms
# 650:	learn: 0.0106227	total: 1.51s	remaining: 812ms
# 651:	learn: 0.0106013	total: 1.52s	remaining: 810ms
# 652:	learn: 0.0105911	total: 1.52s	remaining: 808ms
# 653:	learn: 0.0105784	total: 1.52s	remaining: 805ms
# 654:	learn: 0.0105625	total: 1.52s	remaining: 803ms
# 655:	learn: 0.0105381	total: 1.53s	remaining: 801ms
# 656:	learn: 0.0105134	total: 1.53s	remaining: 798ms
# 657:	learn: 0.0104881	total: 1.53s	remaining: 796ms
# 658:	learn: 0.0104688	total: 1.53s	remaining: 793ms
# 659:	learn: 0.0104443	total: 1.53s	remaining: 791ms
# 660:	learn: 0.0104273	total: 1.54s	remaining: 788ms
# 661:	learn: 0.0104078	total: 1.54s	remaining: 786ms
# 662:	learn: 0.0103930	total: 1.54s	remaining: 784ms
# 663:	learn: 0.0103678	total: 1.54s	remaining: 781ms
# 664:	learn: 0.0103541	total: 1.54s	remaining: 779ms
# 665:	learn: 0.0103431	total: 1.55s	remaining: 776ms
# 666:	learn: 0.0103292	total: 1.55s	remaining: 774ms
# 667:	learn: 0.0103178	total: 1.55s	remaining: 772ms
# 668:	learn: 0.0103066	total: 1.55s	remaining: 769ms
# 669:	learn: 0.0102861	total: 1.56s	remaining: 767ms
# 670:	learn: 0.0102680	total: 1.56s	remaining: 764ms
# 671:	learn: 0.0102507	total: 1.56s	remaining: 762ms
# 672:	learn: 0.0102365	total: 1.56s	remaining: 759ms
# 673:	learn: 0.0102161	total: 1.56s	remaining: 757ms
# 674:	learn: 0.0101954	total: 1.57s	remaining: 754ms
# 675:	learn: 0.0101738	total: 1.57s	remaining: 752ms
# 676:	learn: 0.0101597	total: 1.57s	remaining: 750ms
# 677:	learn: 0.0101440	total: 1.57s	remaining: 747ms
# 678:	learn: 0.0101289	total: 1.57s	remaining: 745ms
# 679:	learn: 0.0101162	total: 1.58s	remaining: 742ms
# 680:	learn: 0.0100912	total: 1.58s	remaining: 740ms
# 681:	learn: 0.0100762	total: 1.58s	remaining: 737ms
# 682:	learn: 0.0100429	total: 1.58s	remaining: 735ms
# 683:	learn: 0.0100094	total: 1.58s	remaining: 733ms
# 684:	learn: 0.0099847	total: 1.59s	remaining: 730ms
# 685:	learn: 0.0099694	total: 1.59s	remaining: 728ms
# 686:	learn: 0.0099512	total: 1.59s	remaining: 725ms
# 687:	learn: 0.0099392	total: 1.59s	remaining: 723ms
# 688:	learn: 0.0099106	total: 1.6s	remaining: 721ms
# 689:	learn: 0.0098980	total: 1.6s	remaining: 718ms
# 690:	learn: 0.0098843	total: 1.6s	remaining: 716ms
# 691:	learn: 0.0098746	total: 1.6s	remaining: 713ms
# 692:	learn: 0.0098575	total: 1.6s	remaining: 711ms
# 693:	learn: 0.0098438	total: 1.61s	remaining: 709ms
# 694:	learn: 0.0098340	total: 1.61s	remaining: 706ms
# 695:	learn: 0.0098190	total: 1.61s	remaining: 704ms
# 696:	learn: 0.0098092	total: 1.61s	remaining: 701ms
# 697:	learn: 0.0097818	total: 1.61s	remaining: 699ms
# 698:	learn: 0.0097715	total: 1.62s	remaining: 697ms
# 699:	learn: 0.0097455	total: 1.62s	remaining: 694ms
# 700:	learn: 0.0097268	total: 1.62s	remaining: 692ms
# 701:	learn: 0.0097076	total: 1.62s	remaining: 689ms
# 702:	learn: 0.0096906	total: 1.63s	remaining: 687ms
# 703:	learn: 0.0096787	total: 1.63s	remaining: 684ms
# 704:	learn: 0.0096571	total: 1.63s	remaining: 682ms
# 705:	learn: 0.0096364	total: 1.63s	remaining: 680ms
# 706:	learn: 0.0096149	total: 1.63s	remaining: 677ms
# 707:	learn: 0.0096041	total: 1.64s	remaining: 675ms
# 708:	learn: 0.0095799	total: 1.64s	remaining: 672ms
# 709:	learn: 0.0095721	total: 1.64s	remaining: 670ms
# 710:	learn: 0.0095494	total: 1.64s	remaining: 667ms
# 711:	learn: 0.0095396	total: 1.64s	remaining: 665ms
# 712:	learn: 0.0095148	total: 1.65s	remaining: 663ms
# 713:	learn: 0.0094922	total: 1.65s	remaining: 660ms
# 714:	learn: 0.0094723	total: 1.65s	remaining: 658ms
# 715:	learn: 0.0094524	total: 1.65s	remaining: 655ms
# 716:	learn: 0.0094443	total: 1.65s	remaining: 653ms
# 717:	learn: 0.0094354	total: 1.66s	remaining: 650ms
# 718:	learn: 0.0094220	total: 1.66s	remaining: 648ms
# 719:	learn: 0.0094107	total: 1.66s	remaining: 646ms
# 720:	learn: 0.0093967	total: 1.66s	remaining: 643ms
# 721:	learn: 0.0093887	total: 1.66s	remaining: 641ms
# 722:	learn: 0.0093788	total: 1.67s	remaining: 638ms
# 723:	learn: 0.0093682	total: 1.67s	remaining: 636ms
# 724:	learn: 0.0093601	total: 1.67s	remaining: 633ms
# 725:	learn: 0.0093448	total: 1.67s	remaining: 631ms
# 726:	learn: 0.0093217	total: 1.67s	remaining: 629ms
# 727:	learn: 0.0093019	total: 1.68s	remaining: 626ms
# 728:	learn: 0.0092897	total: 1.68s	remaining: 624ms
# 729:	learn: 0.0092766	total: 1.68s	remaining: 621ms
# 730:	learn: 0.0092529	total: 1.68s	remaining: 619ms
# 731:	learn: 0.0092440	total: 1.68s	remaining: 617ms
# 732:	learn: 0.0092309	total: 1.69s	remaining: 614ms
# 733:	learn: 0.0092058	total: 1.69s	remaining: 612ms
# 734:	learn: 0.0091825	total: 1.69s	remaining: 609ms
# 735:	learn: 0.0091668	total: 1.69s	remaining: 607ms
# 736:	learn: 0.0091586	total: 1.69s	remaining: 605ms
# 737:	learn: 0.0091463	total: 1.7s	remaining: 602ms
# 738:	learn: 0.0091340	total: 1.7s	remaining: 600ms
# 739:	learn: 0.0091195	total: 1.7s	remaining: 597ms
# 740:	learn: 0.0090908	total: 1.7s	remaining: 595ms
# 741:	learn: 0.0090779	total: 1.7s	remaining: 593ms
# 742:	learn: 0.0090673	total: 1.71s	remaining: 590ms
# 743:	learn: 0.0090570	total: 1.71s	remaining: 588ms
# 744:	learn: 0.0090467	total: 1.71s	remaining: 585ms
# 745:	learn: 0.0090272	total: 1.71s	remaining: 583ms
# 746:	learn: 0.0090135	total: 1.71s	remaining: 581ms
# 747:	learn: 0.0089822	total: 1.72s	remaining: 578ms
# 748:	learn: 0.0089701	total: 1.72s	remaining: 576ms
# 749:	learn: 0.0089575	total: 1.72s	remaining: 573ms
# 750:	learn: 0.0089427	total: 1.72s	remaining: 571ms
# 751:	learn: 0.0089288	total: 1.72s	remaining: 569ms
# 752:	learn: 0.0089127	total: 1.73s	remaining: 566ms
# 753:	learn: 0.0088997	total: 1.73s	remaining: 564ms
# 754:	learn: 0.0088886	total: 1.73s	remaining: 561ms
# 755:	learn: 0.0088747	total: 1.73s	remaining: 559ms
# 756:	learn: 0.0088532	total: 1.73s	remaining: 556ms
# 757:	learn: 0.0088419	total: 1.74s	remaining: 554ms
# 758:	learn: 0.0088311	total: 1.74s	remaining: 552ms
# 759:	learn: 0.0088228	total: 1.74s	remaining: 550ms
# 760:	learn: 0.0088142	total: 1.74s	remaining: 547ms
# 761:	learn: 0.0088056	total: 1.74s	remaining: 545ms
# 762:	learn: 0.0087967	total: 1.75s	remaining: 542ms
# 763:	learn: 0.0087822	total: 1.75s	remaining: 540ms
# 764:	learn: 0.0087525	total: 1.75s	remaining: 538ms
# 765:	learn: 0.0087400	total: 1.75s	remaining: 536ms
# 766:	learn: 0.0087331	total: 1.75s	remaining: 533ms
# 767:	learn: 0.0087186	total: 1.76s	remaining: 531ms
# 768:	learn: 0.0087057	total: 1.76s	remaining: 528ms
# 769:	learn: 0.0086960	total: 1.76s	remaining: 526ms
# 770:	learn: 0.0086827	total: 1.76s	remaining: 524ms
# 771:	learn: 0.0086675	total: 1.76s	remaining: 521ms
# 772:	learn: 0.0086564	total: 1.77s	remaining: 519ms
# 773:	learn: 0.0086392	total: 1.77s	remaining: 517ms
# 774:	learn: 0.0086226	total: 1.77s	remaining: 514ms
# 775:	learn: 0.0086112	total: 1.77s	remaining: 512ms
# 776:	learn: 0.0086015	total: 1.77s	remaining: 510ms
# 777:	learn: 0.0085928	total: 1.78s	remaining: 507ms
# 778:	learn: 0.0085852	total: 1.78s	remaining: 505ms
# 779:	learn: 0.0085762	total: 1.78s	remaining: 503ms
# 780:	learn: 0.0085661	total: 1.78s	remaining: 500ms
# 781:	learn: 0.0085574	total: 1.78s	remaining: 498ms
# 782:	learn: 0.0085488	total: 1.79s	remaining: 495ms
# 783:	learn: 0.0085404	total: 1.79s	remaining: 493ms
# 784:	learn: 0.0085248	total: 1.79s	remaining: 491ms
# 785:	learn: 0.0085183	total: 1.79s	remaining: 488ms
# 786:	learn: 0.0085088	total: 1.79s	remaining: 486ms
# 787:	learn: 0.0084996	total: 1.8s	remaining: 484ms
# 788:	learn: 0.0084767	total: 1.8s	remaining: 481ms
# 789:	learn: 0.0084661	total: 1.8s	remaining: 479ms
# 790:	learn: 0.0084560	total: 1.8s	remaining: 477ms
# 791:	learn: 0.0084451	total: 1.8s	remaining: 474ms
# 792:	learn: 0.0084396	total: 1.81s	remaining: 472ms
# 793:	learn: 0.0084327	total: 1.81s	remaining: 469ms
# 794:	learn: 0.0084199	total: 1.81s	remaining: 467ms
# 795:	learn: 0.0084111	total: 1.81s	remaining: 465ms
# 796:	learn: 0.0084016	total: 1.81s	remaining: 462ms
# 797:	learn: 0.0083792	total: 1.82s	remaining: 460ms
# 798:	learn: 0.0083726	total: 1.82s	remaining: 458ms
# 799:	learn: 0.0083597	total: 1.82s	remaining: 455ms
# 800:	learn: 0.0083493	total: 1.82s	remaining: 453ms
# 801:	learn: 0.0083369	total: 1.82s	remaining: 451ms
# 802:	learn: 0.0083236	total: 1.83s	remaining: 448ms
# 803:	learn: 0.0083128	total: 1.83s	remaining: 446ms
# 804:	learn: 0.0083031	total: 1.83s	remaining: 444ms
# 805:	learn: 0.0082961	total: 1.83s	remaining: 441ms
# 806:	learn: 0.0082840	total: 1.83s	remaining: 439ms
# 807:	learn: 0.0082769	total: 1.84s	remaining: 437ms
# 808:	learn: 0.0082618	total: 1.84s	remaining: 434ms
# 809:	learn: 0.0082564	total: 1.84s	remaining: 432ms
# 810:	learn: 0.0082483	total: 1.84s	remaining: 430ms
# 811:	learn: 0.0082410	total: 1.84s	remaining: 427ms
# 812:	learn: 0.0082315	total: 1.85s	remaining: 425ms
# 813:	learn: 0.0082088	total: 1.85s	remaining: 423ms
# 814:	learn: 0.0081991	total: 1.85s	remaining: 420ms
# 815:	learn: 0.0081902	total: 1.85s	remaining: 418ms
# 816:	learn: 0.0081789	total: 1.85s	remaining: 416ms
# 817:	learn: 0.0081666	total: 1.86s	remaining: 413ms
# 818:	learn: 0.0081550	total: 1.86s	remaining: 411ms
# 819:	learn: 0.0081459	total: 1.86s	remaining: 409ms
# 820:	learn: 0.0081348	total: 1.86s	remaining: 406ms
# 821:	learn: 0.0081254	total: 1.86s	remaining: 404ms
# 822:	learn: 0.0081165	total: 1.87s	remaining: 402ms
# 823:	learn: 0.0081058	total: 1.87s	remaining: 399ms
# 824:	learn: 0.0080985	total: 1.87s	remaining: 397ms
# 825:	learn: 0.0080928	total: 1.87s	remaining: 395ms
# 826:	learn: 0.0080825	total: 1.88s	remaining: 392ms
# 827:	learn: 0.0080742	total: 1.88s	remaining: 390ms
# 828:	learn: 0.0080631	total: 1.88s	remaining: 388ms
# 829:	learn: 0.0080537	total: 1.88s	remaining: 385ms
# 830:	learn: 0.0080424	total: 1.88s	remaining: 383ms
# 831:	learn: 0.0080350	total: 1.89s	remaining: 381ms
# 832:	learn: 0.0080280	total: 1.89s	remaining: 378ms
# 833:	learn: 0.0080169	total: 1.89s	remaining: 376ms
# 834:	learn: 0.0080087	total: 1.89s	remaining: 374ms
# 835:	learn: 0.0080018	total: 1.89s	remaining: 371ms
# 836:	learn: 0.0079844	total: 1.9s	remaining: 369ms
# 837:	learn: 0.0079646	total: 1.9s	remaining: 367ms
# 838:	learn: 0.0079460	total: 1.9s	remaining: 365ms
# 839:	learn: 0.0079308	total: 1.9s	remaining: 362ms
# 840:	learn: 0.0079220	total: 1.9s	remaining: 360ms
# 841:	learn: 0.0079089	total: 1.91s	remaining: 358ms
# 842:	learn: 0.0078962	total: 1.91s	remaining: 355ms
# 843:	learn: 0.0078887	total: 1.91s	remaining: 353ms
# 844:	learn: 0.0078762	total: 1.91s	remaining: 351ms
# 845:	learn: 0.0078685	total: 1.91s	remaining: 348ms
# 846:	learn: 0.0078589	total: 1.92s	remaining: 346ms
# 847:	learn: 0.0078343	total: 1.92s	remaining: 344ms
# 848:	learn: 0.0078265	total: 1.92s	remaining: 341ms
# 849:	learn: 0.0078154	total: 1.92s	remaining: 339ms
# 850:	learn: 0.0078082	total: 1.92s	remaining: 337ms
# 851:	learn: 0.0077997	total: 1.93s	remaining: 335ms
# 852:	learn: 0.0077900	total: 1.93s	remaining: 332ms
# 853:	learn: 0.0077831	total: 1.93s	remaining: 330ms
# 854:	learn: 0.0077778	total: 1.93s	remaining: 328ms
# 855:	learn: 0.0077722	total: 1.93s	remaining: 325ms
# 856:	learn: 0.0077652	total: 1.94s	remaining: 323ms
# 857:	learn: 0.0077590	total: 1.94s	remaining: 321ms
# 858:	learn: 0.0077493	total: 1.94s	remaining: 319ms
# 859:	learn: 0.0077411	total: 1.94s	remaining: 316ms
# 860:	learn: 0.0077364	total: 1.94s	remaining: 314ms
# 861:	learn: 0.0077280	total: 1.95s	remaining: 312ms
# 862:	learn: 0.0077173	total: 1.95s	remaining: 309ms
# 863:	learn: 0.0077083	total: 1.95s	remaining: 307ms
# 864:	learn: 0.0077041	total: 1.95s	remaining: 305ms
# 865:	learn: 0.0076874	total: 1.95s	remaining: 302ms
# 866:	learn: 0.0076710	total: 1.96s	remaining: 300ms
# 867:	learn: 0.0076649	total: 1.96s	remaining: 298ms
# 868:	learn: 0.0076519	total: 1.96s	remaining: 296ms
# 869:	learn: 0.0076412	total: 1.96s	remaining: 293ms
# 870:	learn: 0.0076343	total: 1.96s	remaining: 291ms
# 871:	learn: 0.0076218	total: 1.97s	remaining: 289ms
# 872:	learn: 0.0076162	total: 1.97s	remaining: 286ms
# 873:	learn: 0.0076092	total: 1.97s	remaining: 284ms
# 874:	learn: 0.0076013	total: 1.97s	remaining: 282ms
# 875:	learn: 0.0075956	total: 1.97s	remaining: 279ms
# 876:	learn: 0.0075836	total: 1.98s	remaining: 277ms
# 877:	learn: 0.0075778	total: 1.98s	remaining: 275ms
# 878:	learn: 0.0075712	total: 1.98s	remaining: 273ms
# 879:	learn: 0.0075599	total: 1.98s	remaining: 270ms
# 880:	learn: 0.0075546	total: 1.98s	remaining: 268ms
# 881:	learn: 0.0075442	total: 1.99s	remaining: 266ms
# 882:	learn: 0.0075331	total: 1.99s	remaining: 264ms
# 883:	learn: 0.0075201	total: 1.99s	remaining: 261ms
# 884:	learn: 0.0075122	total: 1.99s	remaining: 259ms
# 885:	learn: 0.0074999	total: 1.99s	remaining: 257ms
# 886:	learn: 0.0074857	total: 2s	remaining: 254ms
# 887:	learn: 0.0074756	total: 2s	remaining: 252ms
# 888:	learn: 0.0074704	total: 2s	remaining: 250ms
# 889:	learn: 0.0074632	total: 2s	remaining: 247ms
# 890:	learn: 0.0074546	total: 2s	remaining: 245ms
# 891:	learn: 0.0074473	total: 2.01s	remaining: 243ms
# 892:	learn: 0.0074400	total: 2.01s	remaining: 241ms
# 893:	learn: 0.0074317	total: 2.01s	remaining: 238ms
# 894:	learn: 0.0074255	total: 2.01s	remaining: 236ms
# 895:	learn: 0.0074138	total: 2.01s	remaining: 234ms
# 896:	learn: 0.0074053	total: 2.02s	remaining: 232ms
# 897:	learn: 0.0073898	total: 2.02s	remaining: 229ms
# 898:	learn: 0.0073823	total: 2.02s	remaining: 227ms
# 899:	learn: 0.0073755	total: 2.02s	remaining: 225ms
# 900:	learn: 0.0073579	total: 2.02s	remaining: 222ms
# 901:	learn: 0.0073382	total: 2.03s	remaining: 220ms
# 902:	learn: 0.0073336	total: 2.03s	remaining: 218ms
# 903:	learn: 0.0073263	total: 2.03s	remaining: 216ms
# 904:	learn: 0.0073202	total: 2.03s	remaining: 213ms
# 905:	learn: 0.0073119	total: 2.03s	remaining: 211ms
# 906:	learn: 0.0073062	total: 2.04s	remaining: 209ms
# 907:	learn: 0.0072945	total: 2.04s	remaining: 207ms
# 908:	learn: 0.0072880	total: 2.04s	remaining: 204ms
# 909:	learn: 0.0072817	total: 2.04s	remaining: 202ms
# 910:	learn: 0.0072737	total: 2.04s	remaining: 200ms
# 911:	learn: 0.0072671	total: 2.05s	remaining: 197ms
# 912:	learn: 0.0072580	total: 2.05s	remaining: 195ms
# 913:	learn: 0.0072530	total: 2.05s	remaining: 193ms
# 914:	learn: 0.0072414	total: 2.05s	remaining: 191ms
# 915:	learn: 0.0072346	total: 2.05s	remaining: 188ms
# 916:	learn: 0.0072201	total: 2.06s	remaining: 186ms
# 917:	learn: 0.0072144	total: 2.06s	remaining: 184ms
# 918:	learn: 0.0072088	total: 2.06s	remaining: 182ms
# 919:	learn: 0.0071995	total: 2.06s	remaining: 179ms
# 920:	learn: 0.0071847	total: 2.06s	remaining: 177ms
# 921:	learn: 0.0071722	total: 2.07s	remaining: 175ms
# 922:	learn: 0.0071655	total: 2.07s	remaining: 173ms
# 923:	learn: 0.0071534	total: 2.07s	remaining: 170ms
# 924:	learn: 0.0071452	total: 2.07s	remaining: 168ms
# 925:	learn: 0.0071328	total: 2.07s	remaining: 166ms
# 926:	learn: 0.0071242	total: 2.08s	remaining: 164ms
# 927:	learn: 0.0071175	total: 2.08s	remaining: 161ms
# 928:	learn: 0.0071068	total: 2.08s	remaining: 159ms
# 929:	learn: 0.0070939	total: 2.08s	remaining: 157ms
# 930:	learn: 0.0070830	total: 2.08s	remaining: 155ms
# 931:	learn: 0.0070775	total: 2.09s	remaining: 152ms
# 932:	learn: 0.0070700	total: 2.09s	remaining: 150ms
# 933:	learn: 0.0070623	total: 2.09s	remaining: 148ms
# 934:	learn: 0.0070566	total: 2.09s	remaining: 145ms
# 935:	learn: 0.0070493	total: 2.09s	remaining: 143ms
# 936:	learn: 0.0070423	total: 2.1s	remaining: 141ms
# 937:	learn: 0.0070362	total: 2.1s	remaining: 139ms
# 938:	learn: 0.0070254	total: 2.1s	remaining: 136ms
# 939:	learn: 0.0070190	total: 2.1s	remaining: 134ms
# 940:	learn: 0.0070046	total: 2.1s	remaining: 132ms
# 941:	learn: 0.0069844	total: 2.11s	remaining: 130ms
# 942:	learn: 0.0069801	total: 2.11s	remaining: 127ms
# 943:	learn: 0.0069722	total: 2.11s	remaining: 125ms
# 944:	learn: 0.0069633	total: 2.11s	remaining: 123ms
# 945:	learn: 0.0069588	total: 2.11s	remaining: 121ms
# 946:	learn: 0.0069449	total: 2.12s	remaining: 118ms
# 947:	learn: 0.0069371	total: 2.12s	remaining: 116ms
# 948:	learn: 0.0069295	total: 2.12s	remaining: 114ms
# 949:	learn: 0.0069194	total: 2.12s	remaining: 112ms
# 950:	learn: 0.0069135	total: 2.13s	remaining: 110ms
# 951:	learn: 0.0069076	total: 2.13s	remaining: 107ms
# 952:	learn: 0.0068935	total: 2.13s	remaining: 105ms
# 953:	learn: 0.0068885	total: 2.13s	remaining: 103ms
# 954:	learn: 0.0068808	total: 2.13s	remaining: 101ms
# 955:	learn: 0.0068746	total: 2.14s	remaining: 98.3ms
# 956:	learn: 0.0068691	total: 2.14s	remaining: 96.1ms
# 957:	learn: 0.0068641	total: 2.14s	remaining: 93.9ms
# 958:	learn: 0.0068575	total: 2.14s	remaining: 91.6ms
# 959:	learn: 0.0068512	total: 2.14s	remaining: 89.4ms
# 960:	learn: 0.0068380	total: 2.15s	remaining: 87.1ms
# 961:	learn: 0.0068282	total: 2.15s	remaining: 84.9ms
# 962:	learn: 0.0068223	total: 2.15s	remaining: 82.7ms
# 963:	learn: 0.0068163	total: 2.15s	remaining: 80.4ms
# 964:	learn: 0.0068025	total: 2.16s	remaining: 78.2ms
# 965:	learn: 0.0067979	total: 2.16s	remaining: 76ms
# 966:	learn: 0.0067887	total: 2.16s	remaining: 73.7ms
# 967:	learn: 0.0067816	total: 2.16s	remaining: 71.5ms
# 968:	learn: 0.0067699	total: 2.16s	remaining: 69.2ms
# 969:	learn: 0.0067614	total: 2.17s	remaining: 67ms
# 970:	learn: 0.0067553	total: 2.17s	remaining: 64.8ms
# 971:	learn: 0.0067507	total: 2.17s	remaining: 62.5ms
# 972:	learn: 0.0067398	total: 2.17s	remaining: 60.3ms
# 973:	learn: 0.0067334	total: 2.17s	remaining: 58ms
# 974:	learn: 0.0067266	total: 2.18s	remaining: 55.8ms
# 975:	learn: 0.0067198	total: 2.18s	remaining: 53.6ms
# 976:	learn: 0.0067160	total: 2.18s	remaining: 51.3ms
# 977:	learn: 0.0067110	total: 2.18s	remaining: 49.1ms
# 978:	learn: 0.0067024	total: 2.18s	remaining: 46.9ms
# 979:	learn: 0.0066908	total: 2.19s	remaining: 44.6ms
# 980:	learn: 0.0066846	total: 2.19s	remaining: 42.4ms
# 981:	learn: 0.0066741	total: 2.19s	remaining: 40.2ms
# 982:	learn: 0.0066659	total: 2.19s	remaining: 37.9ms
# 983:	learn: 0.0066621	total: 2.19s	remaining: 35.7ms
# 984:	learn: 0.0066545	total: 2.2s	remaining: 33.4ms
# 985:	learn: 0.0066436	total: 2.2s	remaining: 31.2ms
# 986:	learn: 0.0066276	total: 2.2s	remaining: 29ms
# 987:	learn: 0.0066221	total: 2.2s	remaining: 26.7ms
# 988:	learn: 0.0066128	total: 2.2s	remaining: 24.5ms
# 989:	learn: 0.0066068	total: 2.21s	remaining: 22.3ms
# 990:	learn: 0.0065999	total: 2.21s	remaining: 20.1ms
# 991:	learn: 0.0065902	total: 2.21s	remaining: 17.8ms
# 992:	learn: 0.0065814	total: 2.21s	remaining: 15.6ms
# 993:	learn: 0.0065717	total: 2.21s	remaining: 13.4ms
# 994:	learn: 0.0065659	total: 2.21s	remaining: 11.1ms
# 995:	learn: 0.0065608	total: 2.22s	remaining: 8.91ms
# 996:	learn: 0.0065530	total: 2.22s	remaining: 6.68ms
# 997:	learn: 0.0065474	total: 2.22s	remaining: 4.45ms
# 998:	learn: 0.0065410	total: 2.22s	remaining: 2.23ms
# 999:	learn: 0.0065359	total: 2.23s	remaining: 0us

# %% [markdown]
# #### SGDClassifier

# %%
start_training = time.time()
    
model_pipeline = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", SGDClassifier(loss='log'))
])

model_pipeline.fit(X_train, y_train)
y_preds = model_pipeline.predict(X_test)

end_training = time.time()
training_time = end_training - start_training
    
model_metrics['SGDClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
    training_time
]
# Out:
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### Metrics

# %%
model_metrics
# Out:
# {'LogisticRegression': [0.9861111111111112,
#   0.9872685185185185,
#   0.9861111111111112,
#   0.9861735798767283,
#   0.06799936294555664],
#  'KNeighborsClassifier': [0.9305555555555556,
#   0.937555114638448,
#   0.9305555555555556,
#   0.928834422657952,
#   0.044023752212524414],
#  'DecisionTreeClassifier': [0.875,
#   0.8938731060606061,
#   0.875,
#   0.8666699170171392,
#   0.02602410316467285],
#  'RandomForestClassifier': [0.9861111111111112,
#   0.9872685185185185,
#   0.9861111111111112,
#   0.9861735798767283,
#   0.20800542831420898],
#  'ExtraTreesClassifier': [0.9722222222222222,
#   0.9764957264957265,
#   0.9722222222222222,
#   0.972387566137566,
#   0.1930370330810547],
#  'SVC': [0.9722222222222222,
#   0.9764957264957265,
#   0.9722222222222222,
#   0.972387566137566,
#   0.0390629768371582],
#  'MLPClassifier': [0.9583333333333334,
#   0.9672619047619047,
#   0.9583333333333334,
#   0.9585185185185185,
#   0.6245205402374268],
#  'AdaBoostClassifier': [0.7777777777777778,
#   0.660300925925926,
#   0.7777777777777778,
#   0.7015366430260047,
#   0.1329963207244873],
#  'XGBClassifier': [0.9583333333333334,
#   0.9619107744107745,
#   0.9583333333333334,
#   0.958577754773407,
#   0.1845076084136963],
#  'LGBMClassifier': [0.9583333333333334,
#   0.9619107744107745,
#   0.9583333333333334,
#   0.958577754773407,
#   0.22500085830688477],
#  'CatBoostClassifier': [0.9722222222222222,
#   0.9764957264957265,
#   0.9722222222222222,
#   0.972387566137566,
#   2.4984867572784424],
#  'SGDClassifier': [0.9861111111111112,
#   0.9872685185185185,
#   0.9861111111111112,
#   0.9861735798767283,
#   0.0360257625579834]}

# %%
df_results = pd.DataFrame.from_dict(model_metrics, orient='index', columns=['Accuracy', 'Precision', 'Recall', 'F1-Score', "training_time"])

df_results
# Out:
#                         Accuracy  Precision    Recall  F1-Score  training_time
# LogisticRegression      0.986111   0.987269  0.986111  0.986174       0.067999
# KNeighborsClassifier    0.930556   0.937555  0.930556  0.928834       0.044024
# DecisionTreeClassifier  0.875000   0.893873  0.875000  0.866670       0.026024
# RandomForestClassifier  0.986111   0.987269  0.986111  0.986174       0.208005
# ExtraTreesClassifier    0.972222   0.976496  0.972222  0.972388       0.193037
# SVC                     0.972222   0.976496  0.972222  0.972388       0.039063
# MLPClassifier           0.958333   0.967262  0.958333  0.958519       0.624521
# AdaBoostClassifier      0.777778   0.660301  0.777778  0.701537       0.132996
# XGBClassifier           0.958333   0.961911  0.958333  0.958578       0.184508
# LGBMClassifier          0.958333   0.961911  0.958333  0.958578       0.225001
# CatBoostClassifier      0.972222   0.976496  0.972222  0.972388       2.498487
# SGDClassifier           0.986111   0.987269  0.986111  0.986174       0.036026

# %% [markdown]
# Looks like the following models have the best metrics:
# - LogisticRegression
# - RandomForestClassifier
# - SGDClassifier

# %% [markdown]
# #### Feature Importance

# %% [markdown]
# ##### Logistic Regression

# %%
log_reg = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", LogisticRegression())
])

log_reg.fit(X_train, y_train)
coefs = log_reg.named_steps["model"].coef_.flatten()
# Out:
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import pandas as pd
# Zip coefficients and names together and make a DataFrame
zipped = zip(X.columns, coefs)
df_features = pd.DataFrame(zipped, columns=["feature", "value"])
# Sort the features by the absolute value of their coefficient
df_features["abs_value"] = df_features["value"].apply(lambda x: abs(x))
df_features["colors"] = df_features["value"].apply(lambda x: "green" if x > 0 else "red")
df_features = df_features.sort_values("abs_value", ascending=False)

# %%
import seaborn as sns
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.barplot(x="feature",
            y="value",
            data=df_features.head(20),
           palette=df_features.head(20)["colors"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontsize=20)
ax.set_title("Top 20 Features", fontsize=25)
ax.set_ylabel("Coef", fontsize=22)
ax.set_xlabel("Feature Name", fontsize=22)
# Out:
# Text(0.5, 0, 'Feature Name')

# %%
from sklearn.metrics import classification_report
y_preds = log_reg.predict(X_test)
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      0.93      0.97        15
#            2       1.00      1.00      1.00        10
#            3       0.92      1.00      0.96        11
#            4       1.00      1.00      1.00         8
#            5       1.00      1.00      1.00         5
#
#     accuracy                           0.99        72
#    macro avg       0.99      0.99      0.99        72
# weighted avg       0.99      0.99      0.99        72

# %%
from sklearn.metrics import ConfusionMatrixDisplay
y_preds = log_reg.predict(X_test)

ConfusionMatrixDisplay.from_predictions(y_true=y_test, 
                                     y_pred=y_preds)

# %% [markdown]
# ### Modeling Takeaways:

# %% [markdown]
# ## Tuning/Improving Model

# %%
random_tuned_metrics = {}

# %%
log_reg_params = {
    "model__C": [0.01, 0.5, 1],
    "model__solver": ['liblinear', 'lbfgs']
}

rf_params = {
    "model__n_estimators": [100, 1000],
    "model__max_depth": [None, 5],
    "model__max_features": ['auto'],
    "model__min_samples_split": [2, 4]
}

sgd_params = {
    "model__loss": ['log_loss', 'perceptron'],
    "model__alpha": [0.001, 0.01]
}

# %% [markdown]
# ### RandomizedSearchCV

# %% [markdown]
# #### Logistic Regression

# %%
log_reg = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", LogisticRegression())
])

log_reg_random_search = RandomizedSearchCV(log_reg,
                                          param_distributions=log_reg_params,
                                          n_iter=10,
                                          cv=5,
                                          verbose=2)
log_reg_random_search.fit(X_train, y_train)
y_preds = log_reg_random_search.predict(X_test)

random_tuned_metrics['LogisticRegression'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
]
# Out:
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# #### Random Forest Classifier

# %%
rf = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", RandomForestClassifier())
])

rf_random_search = RandomizedSearchCV(rf,
                                          param_distributions=rf_params,
                                          n_iter=10,
                                          cv=5,
                                          verbose=2)
rf_random_search.fit(X_train, y_train)
y_preds = rf_random_search.predict(X_test)

random_tuned_metrics['RandomForestClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
]
# Out:
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   2.0s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.8s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.6s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.7s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.6s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.5s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %% [markdown]
# #### SGDClassifier

# %%
sgd = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", SGDClassifier())
])

sgd_random_search = RandomizedSearchCV(sgd,
                                          param_distributions=sgd_params,
                                          n_iter=10,
                                          cv=5,
                                          verbose=2)
sgd_random_search.fit(X_train, y_train)
y_preds = sgd_random_search.predict(X_test)

random_tuned_metrics['SGDClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
]
# Out:
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s

# %%
tuned_results = pd.DataFrame.from_dict(random_tuned_metrics, orient='index', columns=['Accuracy', 'Precision', 'Recall', 'F1-Score'])

tuned_results
# Out:
#                         Accuracy  Precision    Recall  F1-Score
# LogisticRegression      0.972222   0.976496  0.972222  0.972388
# RandomForestClassifier  0.986111   0.987269  0.986111  0.986174
# SGDClassifier           0.986111   0.987269  0.986111  0.986174

# %% [markdown]
# #### Visualize

# %%
tuned_results.plot.bar(figsize=(10, 8))
# Out:
# <Axes: >

# %% [markdown]
# ### GridSearchCV

# %%
grid_tuned_metrics = {}

# %% [markdown]
# #### Logistic Regression

# %%
log_reg = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", LogisticRegression())
])

log_reg_grid_search = GridSearchCV(log_reg,
                                  param_grid=log_reg_params,
                                  cv=5,
                                  verbose=2)
log_reg_grid_search.fit(X_train, y_train)
y_preds = log_reg_grid_search.predict(X_test)

grid_tuned_metrics['LogisticRegression'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
]
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .............model__C=0.01, model__solver=liblinear; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END .................model__C=0.01, model__solver=lbfgs; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..............model__C=0.5, model__solver=liblinear; total time=   0.0s
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# [CV] END ..................model__C=0.5, model__solver=lbfgs; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ................model__C=1, model__solver=liblinear; total time=   0.0s
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# [CV] END ....................model__C=1, model__solver=lbfgs; total time=   0.0s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# #### Random Forest Classifier

# %%
rf = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", RandomForestClassifier())
])

rf_grid_search = GridSearchCV(rf,
                                  param_grid=rf_params,
                                  cv=5,
                                  verbose=2)
rf_grid_search.fit(X_train, y_train)
y_preds = rf_grid_search.predict(X_test)

grid_tuned_metrics['RandomForestClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
]
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.8s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.8s
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.8s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.8s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=None, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.7s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=2, model__n_estimators=1000; total time=   1.6s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=100; total time=   0.1s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.6s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.7s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END model__max_depth=5, model__max_features=auto, model__min_samples_split=4, model__n_estimators=1000; total time=   1.5s
# C:\Users\katie\anaconda3\envs\ml_basics\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %% [markdown]
# #### SGDClassifier

# %%
sgd = Pipeline(steps = [
    ("preprocessor", preprocessor),
    ("model", SGDClassifier())
])

sgd_grid_search = GridSearchCV(sgd,
                                      param_grid=sgd_params,
                                      cv=5,
                                      verbose=2)
sgd_grid_search.fit(X_train, y_train)
y_preds = sgd_grid_search.predict(X_test)

grid_tuned_metrics['SGDClassifier'] = [
    accuracy_score(y_test, y_preds),
    precision_score(y_test, y_preds, average='weighted'),
    recall_score(y_test, y_preds, average='weighted'),
    f1_score(y_test, y_preds, average='weighted'),
]
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END ...........model__alpha=0.001, model__loss=log_loss; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END .........model__alpha=0.001, model__loss=perceptron; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ............model__alpha=0.01, model__loss=log_loss; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s
# [CV] END ..........model__alpha=0.01, model__loss=perceptron; total time=   0.0s

# %% [markdown]
# #### Visualize

# %%
grid_tuned_results = pd.DataFrame.from_dict(grid_tuned_metrics, orient='index', columns=['Accuracy', 'Precision', 'Recall', 'F1-Score'])

grid_tuned_results
# Out:
#                         Accuracy  Precision    Recall  F1-Score
# LogisticRegression      0.972222   0.976496  0.972222  0.972388
# RandomForestClassifier  0.986111   0.987269  0.986111  0.986174
# SGDClassifier           0.986111   0.987269  0.986111  0.986174

# %%
grid_tuned_results.plot.bar(figsize=(10, 8))
# Out:
# <Axes: >

# %% [markdown]
# ### Tuning/Improving Takeaway:
# - RandomSearchCV and GridSearchCV yielded the same metrics given the set of hyperparameters I chose to tweak.
# - Logistic Regression actually dipped by 0.1 from its baseline model metric, while RandomForestClassifier and SGDClassifier both had the same accuracy.

# %% [markdown]
# ## Future Improvements
# - I chose a lot of (but not exhaustive) different classifiers to run a baseline fit of the model for no apparent reason either. In order to crunch down the time of fitting too many, I ought to get familiar with the intricacies of the ensemble and other classification estimators, and pick out the ones that I know would be helpful for this ML task.
#
# - So far, I've been choosing hyperparameters to tweak arbitrarily. There is no real mathematical/scientific reason as to why I chose those set of numbers, or to tweak just those set of hyperparameters. In order to train the model better, I ought to choose these hyperparameters, and their values with good scientific backing/math reasons.
